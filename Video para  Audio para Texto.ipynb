# %% [markdown]
# <a href="https://colab.research.google.com/github/fmbento/Jupyter-Notebooks_ad-hoc-solutions/blob/main/Video%20para%20%20Audio%20para%20Texto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Run this only if these 2 modules aren't yet installed
# !pip install youtube-dl ffmpeg

# %%
# ... same for these 2 modules
# !pip3 install SpeechRecognition pydub

# %% [markdown]
# ## 0. Download / extract audio from youtube videos
# ... that will serve as examples

# %%
# Exemplo EN
# !rm audio.wav
# !youtube-dl --extract-audio --audio-format wav -o audioEN_in.wav https://www.youtube.com/watch?v=BHtDLadc7Fo

# %%
# On local JNB server:
import subprocess
command = 'ffmpeg -i /home/jovyan/audioEN_in.wav -ab 160k -ar 44100 -vn /home/jovyan/audioEN.wav'
subprocess.call(command, shell=True)

# %%
# On Google Colab or any other Cloud based JNB server:
import subprocess
command = 'ffmpeg -i audioEN_in.wav -ab 160k -ar 44100 -vn audioEN.wav'
subprocess.call(command, shell=True)
# Out:
# 0

# %%
# Exemplo PT
# !rm audioPT.wav
# !youtube-dl --extract-audio --audio-format wav -o audioPT_in.wav https://www.youtube.com/watch?v=r8y571SrVe4
# Out:
# [download] 100% of 8.42MiB in 02:09
# [ffmpeg] Correcting container in "audioPT_in.wav"
# [ffmpeg] Post-process file audioPT_in.wav exists, skipping

# %%
# On local JNB server:
command = 'ffmpeg -i /home/jovyan/audioPT_in.wav -ab 160k -ar 44100 -vn /home/jovyan/audioPT.wav'
subprocess.call(command, shell=True)
# Out:
# 1

# %%
# On Google Colab or any other Cloud based JNB server:
command = 'ffmpeg -i audioPT_in.wav -ab 160k -ar 44100 -vn audioPT.wav'
subprocess.call(command, shell=True)
# Out:
# 0

# %% [markdown]
# ## 1. Extrair o Audio para um ficheiro "audio.wav" (de um ficheiro local)

# %%
# import subprocess
# command = 'ffmpeg -i /home/jovyan/2023-01-11.mp4 -ab 160k -ar 44100 -vn /home/jovyan/audio.wav'
#subprocess.call(command, shell=True)

# %% [markdown]
# ## 2. Iniciar o Recognizer

# %%
import speech_recognition as sr
# initialize the recognizer
r = sr.Recognizer()

# %% [markdown]
# ## 3. Função que divide o ficheiro audio em pedaços de alguns segundos
# #### (detecção de frases) e faz o respectivo reconhecimento de cada pedaço
# Deste modo não é necessário fazer o upload para a Cloud do Google -- a separação entre pedaços é feita com base nos momentos de pausa entre palavras para não as cortar a meio.
#
# #### Para Português deve-se invocar o Recognizer com a flag language="pt-PT"
# r.recognize_google(audio_data, language="pt-PT")

# %%
# importing libraries 
import speech_recognition as sr 
import os 
from pydub import AudioSegment
from pydub.silence import split_on_silence

# create a speech recognition object
r = sr.Recognizer()

# a function that splits the audio file into chunks
# and applies speech recognition
def get_large_audio_transcription(path, lang):
    """
    Splitting the large audio file into chunks
    and apply speech recognition on each of these chunks
    """
    # open the audio file using pydub
    sound = AudioSegment.from_wav(path)  
    # split audio sound where silence is 700 miliseconds or more and get chunks
    chunks = split_on_silence(sound,
        # experiment with this value for your target audio file
        min_silence_len = 500,
        # adjust this per requirement
        silence_thresh = sound.dBFS-14,
        # keep the silence for 1 second, adjustable as well
        keep_silence=500,
    )
    folder_name = "audio-chunks"
    # create a directory to store the audio chunks
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    whole_text = ""
    # process each chunk 
    for i, audio_chunk in enumerate(chunks, start=1):
        # export audio chunk and save it in
        # the `folder_name` directory.
        chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
        audio_chunk.export(chunk_filename, format="wav")
        # recognize the chunk
        with sr.AudioFile(chunk_filename) as source:
            audio_listened = r.record(source)
            # try converting it to text
            try:
                text = r.recognize_google(audio_listened, language=lang)
            except sr.UnknownValueError as e:
                print("Error:", str(e))
            else:
                text = f"{text.capitalize()}. "
                print(chunk_filename, ":", text)
                whole_text += text
    # return the text for all chunks detected
    return whole_text

# %% [markdown]
# ## 3. Executar a função com o audio extraído do video
# A saída é apresentada a seguir a "Todo o Texto"

# %%
# EN
path = "audioEN.wav"
Text_EN = get_large_audio_transcription(path, "en-UK")
print("\nTexto EN:", Text_EN)
# Out:
# result2:
# {   'alternative': [   {   'confidence': 0.96975756,
#                            'transcript': 'my name is Greg and in this video '
#                                          "I'm going to teach you how you can "
#                                          'evaluate your own level of English '
#                                          'according to the common European '
#                                          'framework of reference for '
#                                          'languages'},
#                        {   'transcript': "my name's Greg and in this video I'm "
#                                          'going to teach you how you can '
#                                          'evaluate your own level of English '
#                                          'according to the common European '
#                                          'framework of reference for '
#                                          'languages'},
#                        {   'transcript': 'my name is Greg and in this video '
#                                          "I'm going to teach you how you can "
#                                          'evaluate your own level of English '
#                                          'according to the common European '
#                                          'framework of reference four '
#                                          'languages'},
#                        {   'transcript': 'my name is Greg and in this video '
#                                          "I'm going to teach you how you can "
#                                          'evaluate your own level of English '
#                                          'according to the common European '
#                                          'framework of a reference for '
#                                          'languages'}],
#     'final': True}
# audio-chunks/chunk1.wav : My name is greg and in this video i'm going to teach you how you can evaluate your own level of english according to the common european framework of reference for languages.
# result2:
# {   'alternative': [   {'confidence': 0.95649147, 'transcript': "so let's go"},
#                        {'transcript': "so well let's go"},
#                        {'transcript': 'so lets go'},
#                        {'transcript': "so we'll let go"},
#                        {'transcript': "so we'll let's go"}],
#     'final': True}
# audio-chunks/chunk2.wav : So let's go.
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.96284938,
#                            'transcript': 'basically the common European '
#                                          'framework of reference for languages '
#                                          'is divided into six different levels '
#                                          'they are A1 A2 B1 B2'},
#                        {   'transcript': 'basically the common European '
#                                          'framework of reference for languages '
#                                          'is divided into six different levels '
#                                          'they are a1a2b1 B2'},
#                        {   'transcript': 'basically the common European '
#                                          'framework of reference for languages '
#                                          'is divided into six different levels '
#                                          'they are a1a2 B1 B2'},
#                        {   'transcript': 'basically the common European '
#                                          'framework of reference for languages '
#                                          'is divided into six different levels '
#                                          'they are A1 a2b1 B2'},
#                        {   'transcript': 'basically the common European '
#                                          'framework of reference for languages '
#                                          'is divided into six different levels '
#                                          'they are A1 A2 b1b2'}],
#     'final': True}
# audio-chunks/chunk4.wav : Basically the common european framework of reference for languages is divided into six different levels they are a1 a2 b1 b2.
# result2:
# {   'alternative': [   {   'confidence': 0.96145618,
#                            'transcript': 'C1 and C2 now we can think of the a '
#                                          'levels to be beginner levels'},
#                        {   'transcript': 'the C1 and C2 now we can think of '
#                                          'the a levels to be beginner levels'},
#                        {   'transcript': 'C1 and C2 now we can think of the a '
#                                          'levels to be bigger levels'},
#                        {   'transcript': 'the C1 and C2 now we can think of '
#                                          'the a levels to be bigger levels'}],
#     'final': True}
# audio-chunks/chunk5.wav : C1 and c2 now we can think of the a levels to be beginner levels.
# result2:
# {   'alternative': [   {   'confidence': 0.93390787,
#                            'transcript': 'the B levels to be intermediate '
#                                          'levels'},
#                        {   'transcript': 'the bee levels to be intermediate '
#                                          'levels'},
#                        {   'transcript': 'the b-levels to be intermediate '
#                                          'levels'}],
#     'final': True}
# audio-chunks/chunk6.wav : The b levels to be intermediate levels.
# result2:
# {   'alternative': [   {   'confidence': 0.96262062,
#                            'transcript': 'on the sea levels to be Advanced '
#                                          "levels we're going to look at each "
#                                          'of these levels so that you can '
#                                          'evaluate your own level of English '
#                                          'this will enable you to know which '
#                                          'exam you should be preparing and it '
#                                          'will also enable you to give your '
#                                          'future employers and idea of what '
#                                          'English level you currently have and '
#                                          'after watching this video I want you '
#                                          'to write a comment telling me what '
#                                          'level you have'},
#                        {   'transcript': 'and the sea levels to be Advanced '
#                                          "levels we're going to look at each "
#                                          'of these levels so that you can '
#                                          'evaluate your own level of English '
#                                          'this will enable you to know which '
#                                          'exam you should be preparing and it '
#                                          'will also enable you to give your '
#                                          'future employers and idea of what '
#                                          'English level you currently have and '
#                                          'after watching this video I want you '
#                                          'to write a comment telling me what '
#                                          'level you have'},
#                        {   'transcript': 'on the sea levels to be Advanced '
#                                          "levels we're going to look at each "
#                                          'of these levels so that you can '
#                                          'evaluate your own level of English '
#                                          'this will enable you to know which '
#                                          'exam you should be preparing and it '
#                                          'will also enable you to give your '
#                                          'future employers and an idea of what '
#                                          'English level you currently have and '
#                                          'after watching this video I want you '
#                                          'to write a comment telling me what '
#                                          'level you have'},
#                        {   'transcript': 'on the sea levels to be Advanced '
#                                          "levels we're going to look at each "
#                                          'of these levels so that you can '
#                                          'evaluate your own level of English '
#                                          'this will enable you to know which '
#                                          'exam you should be preparing and it '
#                                          'will also enable you to give your '
#                                          'future employers and idea of what '
#                                          'English level you currently have and '
#                                          'after watching this video I want you '
#                                          'to write a comment telling me what '
#                                          'level do you have'}],
#     'final': True}
# audio-chunks/chunk7.wav : On the sea levels to be advanced levels we're going to look at each of these levels so that you can evaluate your own level of english this will enable you to know which exam you should be preparing and it will also enable you to give your future employers and idea of what english level you currently have and after watching this video i want you to write a comment telling me what level you have.
# result2:
# {   'alternative': [   {   'confidence': 0.95242167,
#                            'transcript': 'and what level of English you want'},
#                        {'transcript': 'and what level of English you'}],
#     'final': True}
# audio-chunks/chunk8.wav : And what level of english you want.
# result2:
# []
# Error:
# result2:
# []
# Error:
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.97160846,
#                            'transcript': 'A1 is the beginner level of English '
#                                          'and this is the equivalent to the '
#                                          'Cambridge Young Learners exam called '
#                                          'movers you have an A1 level of '
#                                          'English if you can understand and '
#                                          'use very basic expressions in '
#                                          'English you can introduce yourself '
#                                          'and ask questions about personal '
#                                          'details of other people and you can '
#                                          'interact with other people if they '
#                                          'speak slowly'},
#                        {   'transcript': 'A1 is the beginner level of English '
#                                          'and this is the equivalent to the '
#                                          'Cambridge Young Learners exam called '
#                                          'movers you have an A1 level of '
#                                          'English if you can understand and '
#                                          'use very basic expressions in '
#                                          'English you can introduce yourself '
#                                          'and ask questions about personal '
#                                          'details of all the people and you '
#                                          'can interact with other people if '
#                                          'they speak slowly'}],
#     'final': True}
# audio-chunks/chunk12.wav : A1 is the beginner level of english and this is the equivalent to the cambridge young learners exam called movers you have an a1 level of english if you can understand and use very basic expressions in english you can introduce yourself and ask questions about personal details of other people and you can interact with other people if they speak slowly.
# result2:
# {   'alternative': [   {   'confidence': 0.96348882,
#                            'transcript': 'and if they are prepared to really '
#                                          'modify their language and make an '
#                                          'effort to be understood by you'},
#                        {   'transcript': 'and if they are prepared to really '
#                                          'modify that language and make an '
#                                          'effort to be understood by you'},
#                        {   'transcript': 'and if they are prepared to really '
#                                          'modify the language and make an '
#                                          'effort to be understood by you'}],
#     'final': True}
# audio-chunks/chunk13.wav : And if they are prepared to really modify their language and make an effort to be understood by you.
# result2:
# []
# Error:
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.95061553,
#                            'transcript': 'the A2 level can be described as '
#                                          'Elementary'},
#                        {   'transcript': 'the a two level can be described as '
#                                          'Elementary'},
#                        {   'transcript': 'the a two-level can be described as '
#                                          'Elementary'},
#                        {   'transcript': 'the A2 level can be described as '
#                                          'alimentary'},
#                        {   'transcript': 'the A2 level can be described as an '
#                                          'elementary'}],
#     'final': True}
# audio-chunks/chunk16.wav : The a2 level can be described as elementary.
# result2:
# {   'alternative': [   {   'confidence': 0.95784163,
#                            'transcript': 'and this is the equivalent to the '
#                                          'Cambridge Young Learners exam called '
#                                          'Flyers now if you have an A2 level '
#                                          'of English you can understand'},
#                        {   'transcript': 'and this is the equivalent to the '
#                                          'Cambridge jungle Learners exam '
#                                          'called Flyers now if you have an A2 '
#                                          'level of English you can understand'},
#                        {   'transcript': 'and this is the equivalent to the '
#                                          'Cambridge Learners exam called '
#                                          'Flyers now if you have an A2 level '
#                                          'of English you can understand'},
#                        {   'transcript': 'and this is the equivalent to the '
#                                          'Cambridge younger Learners exam '
#                                          'called Flyers now if you have an A2 '
#                                          'level of English you can understand'},
#                        {   'transcript': 'and this is the equivalent to the '
#                                          'Cambridge Young Learners exam called '
#                                          'Flyers now if you have an a two '
#                                          'level of English you can '
#                                          'understand'}],
#     'final': True}
# audio-chunks/chunk17.wav : And this is the equivalent to the cambridge young learners exam called flyers now if you have an a2 level of english you can understand.
# result2:
# {   'alternative': [   {   'confidence': 0.96265841,
#                            'transcript': 'frequently used Expressions about '
#                                          'common topics such as shopping '
#                                          'travel work and local geography like '
#                                          'your town or where you live'},
#                        {   'transcript': 'frequently used Expressions about '
#                                          'come and topics such as shopping '
#                                          'travel work and local geography like '
#                                          'your town or where you live'},
#                        {   'transcript': 'frequently used Expressions about '
#                                          'come on topics such as shopping '
#                                          'travel work and local geography like '
#                                          'your town or where you live'},
#                        {   'transcript': 'frequently used Expressions about '
#                                          'common topics such as shopping '
#                                          'travel work and local geography like '
#                                          "you're town or where you live"},
#                        {   'transcript': 'frequently used Expressions about '
#                                          'common topics such as shopping '
#                                          'travel work and local geography like '
#                                          'your town or where you'}],
#     'final': True}
# audio-chunks/chunk18.wav : Frequently used expressions about common topics such as shopping travel work and local geography like your town or where you live.
# result2:
# {   'alternative': [   {   'confidence': 0.97198421,
#                            'transcript': 'you can describe in simple terms '
#                                          'about your background about your '
#                                          'life and about your environment '
#                                          'about where you live'},
#                        {   'transcript': 'you can describe a simple terms '
#                                          'about your background about your '
#                                          'life and about your environment '
#                                          'about where you live'}],
#     'final': True}
# audio-chunks/chunk19.wav : You can describe in simple terms about your background about your life and about your environment about where you live.
# result2:
# {   'alternative': [   {   'confidence': 0.97152883,
#                            'transcript': 'but again in simple terms'},
#                        {'transcript': 'but again in a simple terms'}],
#     'final': True}
# audio-chunks/chunk20.wav : But again in simple terms.
# result2:
# []
# Error:
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.96224797,
#                            'transcript': 'now most people I deal with have an '
#                                          'intermediate level of English and in '
#                                          'my business I help take them to an '
#                                          'advanced level of English'},
#                        {   'transcript': 'found most people I deal with have '
#                                          'an intermediate level of English and '
#                                          'in my business I help take them to '
#                                          'an advanced level of English'},
#                        {   'transcript': 'about most people I deal with have '
#                                          'an intermediate level of English and '
#                                          'in my business I help take them to '
#                                          'an advanced level of English'},
#                        {   'transcript': 'now most people I deal with have an '
#                                          'intermediate level of English and in '
#                                          'my business I helped take them to an '
#                                          'advanced level of English'},
#                        {   'transcript': 'now most people I deal with have an '
#                                          'intermediate level of English and in '
#                                          'my business I help take them to an '
#                                          'advance level of English'}],
#     'final': True}
# audio-chunks/chunk23.wav : Now most people i deal with have an intermediate level of english and in my business i help take them to an advanced level of english.
# result2:
# {   'alternative': [   {   'confidence': 0.9626081,
#                            'transcript': 'intermediate is divided into two '
#                                          'parts B1 and B2 B1 is the equivalent '
#                                          'to the Cambridge preliminary exam'},
#                        {   'transcript': 'intermediate is divided into two '
#                                          'parts B1 and b2b1 is the equivalent '
#                                          'to the Cambridge preliminary exam'},
#                        {   'transcript': 'intermediate is divided into two '
#                                          'parts B1 and B two B1 is the '
#                                          'equivalent to the Cambridge '
#                                          'preliminary exam'},
#                        {   'transcript': 'intermediate is divided into two '
#                                          'parts B1 and B 2 B1 is the '
#                                          'equivalent to the Cambridge '
#                                          'preliminary exam'},
#                        {   'transcript': 'intermediate is divided into two '
#                                          'parts B1 and B2 B1 is the equivalent '
#                                          'to the Cambridge preliminary '
#                                          'example'}],
#     'final': True}
# audio-chunks/chunk24.wav : Intermediate is divided into two parts b1 and b2 b1 is the equivalent to the cambridge preliminary exam.
# result2:
# {   'alternative': [   {   'confidence': 0.96319687,
#                            'transcript': 'pet Pilots level 4 and the TOEFL '
#                                          'score between 57 and 86 you have a '
#                                          'B1 level if you can understand '
#                                          'points related to family'},
#                        {   'transcript': 'pet Pilots level four and the TOEFL '
#                                          'score between 57 and 86 you have a '
#                                          'B1 level if you can understand '
#                                          'points related to family'},
#                        {   'transcript': 'pet Pilots level 4 and the TOEFL '
#                                          'score between 57 and 86 you have a '
#                                          'B1 level if you can understand '
#                                          'points related to family work'},
#                        {   'transcript': 'pet Pilots level four and the TOEFL '
#                                          'score between 57 and 86 you have a '
#                                          'B1 level if you can understand '
#                                          'points related to family work'},
#                        {   'transcript': 'pet Pilots level 4 and the TOEFL '
#                                          'score between 57 and 86 you have a '
#                                          'B-1 level if you can understand '
#                                          'points related to family'}],
#     'final': True}
# audio-chunks/chunk25.wav : Pet pilots level 4 and the toefl score between 57 and 86 you have a b1 level if you can understand points related to family.
# result2:
# {   'alternative': [   {   'confidence': 0.94721907,
#                            'transcript': 'Elijah and school'},
#                        {'transcript': 'Elijah on school'},
#                        {'transcript': 'Eliza and school'},
#                        {'transcript': 'Elisha and school'},
#                        {'transcript': 'Elijah and Skool'}],
#     'final': True}
# audio-chunks/chunk26.wav : Elijah and school.
# result2:
# {   'alternative': [   {   'confidence': 0.97164607,
#                            'transcript': 'and if you can deal with most travel '
#                                          'situations'},
#                        {   'transcript': 'if you can deal with most travel '
#                                          'situations'}],
#     'final': True}
# audio-chunks/chunk27.wav : And if you can deal with most travel situations.
# result2:
# {   'alternative': [   {   'confidence': 0.95822072,
#                            'transcript': 'like going to the airport going to '
#                                          'restaurants checking in at a hotel'},
#                        {   'transcript': 'like going to the airport going to '
#                                          'restaurant checking in at a hotel'},
#                        {   'transcript': 'like going to the airport going to a '
#                                          'restaurant checking in at a hotel'},
#                        {   'transcript': 'like going to the airport going to a '
#                                          'restaurants checking in at a hotel'},
#                        {   'transcript': 'like going to the airport going to '
#                                          'restaurants checking in at the '
#                                          'hotel'}],
#     'final': True}
# audio-chunks/chunk28.wav : Like going to the airport going to restaurants checking in at a hotel.
# result2:
# {   'alternative': [   {   'confidence': 0.96349341,
#                            'transcript': 'typical travel situations you can '
#                                          'write text about topics of personal '
#                                          'interest and you can describe both '
#                                          'in spoken English and written '
#                                          'English experiences events dreams '
#                                          'Ambitions and also give brief '
#                                          'opinions on things and talk about '
#                                          'your plans if you can do all that in '
#                                          'English you have a B1 level'},
#                        {   'transcript': 'typical travel situations you can '
#                                          'write text about topics of personal '
#                                          'interest and you can describe both '
#                                          'in spoken English and written '
#                                          'English experiences events dreams '
#                                          'Ambitions and also give brief '
#                                          'opinions on things and talk about '
#                                          'your plans if you can do all that in '
#                                          'English you have a big one level'},
#                        {   'transcript': 'typical travel situations you can '
#                                          'write texts about topics of personal '
#                                          'interest and you can describe both '
#                                          'in spoken English and written '
#                                          'English experiences events dreams '
#                                          'Ambitions and also give brief '
#                                          'opinions on things and talk about '
#                                          'your plans if you can do all that in '
#                                          'English you have a B1 level'},
#                        {   'transcript': 'typical travel situations you can '
#                                          'write text about topics of personal '
#                                          'interest and you can describe both '
#                                          'in spoken English and written '
#                                          'English experiences events dreams '
#                                          'Ambitions and also give brief '
#                                          'opinions on things and talk about '
#                                          'your plans if you can do all that in '
#                                          'English you have a beat one level'},
#                        {   'transcript': 'typical travel situations you can '
#                                          'write texts about topics of personal '
#                                          'interest and you can describe both '
#                                          'in spoken English and written '
#                                          'English experiences events dreams '
#                                          'Ambitions and also give brief '
#                                          'opinions on things and talk about '
#                                          'your plans if you can do all that in '
#                                          'English you have a beat one level'}],
#     'final': True}
# audio-chunks/chunk29.wav : Typical travel situations you can write text about topics of personal interest and you can describe both in spoken english and written english experiences events dreams ambitions and also give brief opinions on things and talk about your plans if you can do all that in english you have a b1 level.
# result2:
# []
# Error:
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.96311682,
#                            'transcript': 'B2 is considered to be Upper '
#                                          'Intermediate and this is the '
#                                          'equivalent of the Cambridge first '
#                                          'certificate of English'},
#                        {   'transcript': 'B2 is considered to be up '
#                                          'intermediate and this is the '
#                                          'equivalent of the Cambridge first '
#                                          'certificate of English'},
#                        {   'transcript': 'B2 is considered to be open '
#                                          'intermediate and this is the '
#                                          'equivalent of the Cambridge first '
#                                          'certificate of English'},
#                        {   'transcript': 'B2 is considered to be Upper '
#                                          'Intermediate and this is the '
#                                          'equivalent of the Cambridge 1st '
#                                          'certificate of English'}],
#     'final': True}
# audio-chunks/chunk32.wav : B2 is considered to be upper intermediate and this is the equivalent of the cambridge first certificate of english.
# result2:
# {   'alternative': [   {   'confidence': 0.95744771,
#                            'transcript': "I don't level five to six and a "
#                                          'total score of between 87 and 109 B2 '
#                                          'is usually the minimum requirement '
#                                          'that companies ask for if English '
#                                          "isn't an extremely important part of "
#                                          'their job'},
#                        {   'transcript': "I don't level five to six and a "
#                                          'tuffle score of between 87 and 109 '
#                                          'B2 is usually the minimum '
#                                          'requirement that companies ask for '
#                                          "if English isn't an extremely "
#                                          'important part of their job'},
#                        {   'transcript': "I don't level five to six and a "
#                                          'TOEFL score of between 87 and 109 B2 '
#                                          'is usually the minimum requirement '
#                                          'that companies ask for if English '
#                                          "isn't an extremely important part of "
#                                          'their job'},
#                        {   'transcript': "I don't level five to six and a "
#                                          'total score of between 87 and 109 B2 '
#                                          'is usually the minimum requirement '
#                                          'that companies ask for if English '
#                                          "isn't an extremely important part of "
#                                          'the job'},
#                        {   'transcript': "I don't level five to six and a "
#                                          'tuffle score of between 87 and 109 '
#                                          'B2 is usually the minimum '
#                                          'requirement that companies ask for '
#                                          "if English isn't an extremely "
#                                          'important part of the job'}],
#     'final': True}
# audio-chunks/chunk33.wav : I don't level five to six and a total score of between 87 and 109 b2 is usually the minimum requirement that companies ask for if english isn't an extremely important part of their job.
# result2:
# {   'alternative': [   {   'confidence': 0.97164369,
#                            'transcript': 'you have a B2 level of English if '
#                                          'you can understand the main ideas of '
#                                          'a more technical text you will also '
#                                          'be able to communicate spontaneously '
#                                          'with a native speaker without too '
#                                          'much effort for you'},
#                        {   'transcript': 'you have a B-2 level of English if '
#                                          'you can understand the main ideas of '
#                                          'a more technical text you will also '
#                                          'be able to communicate spontaneously '
#                                          'with a native speaker without too '
#                                          'much effort for you'},
#                        {   'transcript': 'you have a B2 level of English if '
#                                          'you can understand the main ideas of '
#                                          'a more technical text you will also '
#                                          'be able to communicate spontaneously '
#                                          'with a native speaker without too '
#                                          'much effort to you'},
#                        {   'transcript': 'you have a B2 level of English if '
#                                          'you can understand the main ideas of '
#                                          'a more technical text you will also '
#                                          'be able to communicate spontaneously '
#                                          'within native speaker without too '
#                                          'much effort for you'}],
#     'final': True}
# audio-chunks/chunk34.wav : You have a b2 level of english if you can understand the main ideas of a more technical text you will also be able to communicate spontaneously with a native speaker without too much effort for you.
# result2:
# {   'alternative': [   {   'confidence': 0.97029877,
#                            'transcript': 'or without too much effort for the '
#                                          'native speaker to understand you and '
#                                          'spontaneously means just reacting '
#                                          'naturally to the questions they '
#                                          'asked you without having to stop and '
#                                          'really think about how to construct '
#                                          'the sentence or how to find the '
#                                          'correct piece of vocabulary you will '
#                                          'also be able to write a text on a '
#                                          'wide variety of subjects in a wide '
#                                          'variety of styles'},
#                        {   'transcript': 'or without too much effort for the '
#                                          'native speaker to understand you and '
#                                          'spontaneously means just reacting '
#                                          'naturally to the questions they '
#                                          'asked you without having to stop and '
#                                          'really think about how to construct '
#                                          'the sentence or how to find the '
#                                          'correct piece of vocabulary you will '
#                                          'also be able to write a text on our '
#                                          'wide variety of subjects in a wide '
#                                          'variety of styles'},
#                        {   'transcript': 'or without too much effort for the '
#                                          'native speaker to understand you and '
#                                          'spontaneously means just reacting '
#                                          'naturally to the questions they '
#                                          'asked you without having to stop and '
#                                          'really think about how to construct '
#                                          'the sentence or how to find the '
#                                          'correct piece of vocabulary you will '
#                                          'also be able to write a text on a '
#                                          'wide variety of subjects in a wide '
#                                          'variety of Stiles'},
#                        {   'transcript': 'or without too much effort for the '
#                                          'native speaker to understand you and '
#                                          'spontaneously means just reacting '
#                                          'naturally to the questions they '
#                                          'asked you without having to stop and '
#                                          'really think about how to construct '
#                                          'the sentence or how to find the '
#                                          'correct piece of vocabulary you will '
#                                          'also be able to write a text on a '
#                                          'wide variety of subjects in a wide '
#                                          'variety of style'},
#                        {   'transcript': 'or without too much effort for the '
#                                          'native speaker to understand you and '
#                                          'spontaneously means just reacting '
#                                          'naturally to the questions they '
#                                          'asked you without having to stop and '
#                                          'really think about how to construct '
#                                          'the sentence or how to find the '
#                                          'correct piece of vocabulary you will '
#                                          'also be able to write a text on our '
#                                          'wide variety of subjects in a wide '
#                                          'variety of Stiles'}],
#     'final': True}
# audio-chunks/chunk35.wav : Or without too much effort for the native speaker to understand you and spontaneously means just reacting naturally to the questions they asked you without having to stop and really think about how to construct the sentence or how to find the correct piece of vocabulary you will also be able to write a text on a wide variety of subjects in a wide variety of styles.
# result2:
# {   'alternative': [   {   'confidence': 0.97135246,
#                            'transcript': 'giving your opinions and pointing '
#                                          'out the advantages and disadvantages '
#                                          'of common topics'},
#                        {   'transcript': 'giving your opinions and pointing '
#                                          'out the advantages and disadvantages '
#                                          'of coming topics'},
#                        {   'transcript': 'giving your opinions and pointing '
#                                          'out the advantages and disadvantages '
#                                          'of come on topics'},
#                        {   'transcript': 'giving your opinions and pointing '
#                                          'out the advantages and disadvantages '
#                                          'of come and topics'},
#                        {   'transcript': 'giving your opinions and pointing '
#                                          'out the advantages and disadvantages '
#                                          'of comment topics'}],
#     'final': True}
# audio-chunks/chunk36.wav : Giving your opinions and pointing out the advantages and disadvantages of common topics.
# result2:
# []
# Error:
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.96628487,
#                            'transcript': 'we then move on to the advanced '
#                                          'levels of English C1 and C2 now in '
#                                          'my experience C1 is a level of '
#                                          'English that most students want to '
#                                          'reach and normally when companies '
#                                          'ask for a high level of English '
#                                          "they're asking for a C1 level this "
#                                          'is the equivalent of the Cambridge '
#                                          "Advanced exam I don't level seven a "
#                                          'total score of between 110 and 120 '
#                                          'and atomic score of 880'},
#                        {   'transcript': 'we then move on to the advanced '
#                                          'levels of English C1 and C2 now in '
#                                          'my experience C1 is a level of '
#                                          'English that most students want to '
#                                          'reach and normally when companies '
#                                          'ask for a high level of English '
#                                          "they're asking for a C1 level this "
#                                          'is the equivalent of the Cambridge '
#                                          "Advanced exam I don't level 7 a "
#                                          'total score of between 110 and 120 '
#                                          'and atomic score of 880'},
#                        {   'transcript': 'we then move on to the advanced '
#                                          'levels of English C1 and C2 now in '
#                                          'my experience C1 is a level of '
#                                          'English that most students want to '
#                                          'reach and normally when companies '
#                                          'ask for a high level of English '
#                                          "they're asking for a C1 level this "
#                                          'is the equivalent of the Cambridge '
#                                          "Advanced exam I don't level seven a "
#                                          'total score of between 110 and 120 '
#                                          'and atoic score of 880'},
#                        {   'transcript': 'we then move on to the advanced '
#                                          'levels of English C1 and C2 now in '
#                                          'my experience C1 is a level of '
#                                          'English that most students want to '
#                                          'reach and normally when companies '
#                                          'ask for a high level of English '
#                                          "they're asking for a C1 level this "
#                                          'is the equivalent of the Cambridge '
#                                          "Advanced exam I don't level 7 a "
#                                          'total score of between 110 and 120 '
#                                          'and atoic score of 880'},
#                        {   'transcript': 'we then move on to the advanced '
#                                          'levels of English C1 and C2 now in '
#                                          'my experience C1 is a level of '
#                                          'English that most students want to '
#                                          'reach and normally when companies '
#                                          'ask for a high level of English '
#                                          "they're asking for a C1 level this "
#                                          'is the equivalent of the Cambridge '
#                                          "Advanced exam I don't level seven a "
#                                          'total score of between 110 and 120 '
#                                          'and atomic score of 88'}],
#     'final': True}
# audio-chunks/chunk39.wav : We then move on to the advanced levels of english c1 and c2 now in my experience c1 is a level of english that most students want to reach and normally when companies ask for a high level of english they're asking for a c1 level this is the equivalent of the cambridge advanced exam i don't level seven a total score of between 110 and 120 and atomic score of 880.
# result2:
# {   'alternative': [   {   'confidence': 0.96578699,
#                            'transcript': 'if you have a C1 level of English '
#                                          'you will be able to understand a '
#                                          'wide range of long texts long '
#                                          'articles'},
#                        {   'transcript': 'if you have a c-1 level of English '
#                                          'you will be able to understand a '
#                                          'wide range of long texts long '
#                                          'articles'},
#                        {   'transcript': 'if you have a C1 level of English '
#                                          'you will be able to understand a '
#                                          'wide range of long texts lung '
#                                          'articles'},
#                        {   'transcript': 'if you have a c-1 level of English '
#                                          'you will be able to understand a '
#                                          'wide range of long texts lung '
#                                          'articles'}],
#     'final': True}
# audio-chunks/chunk40.wav : If you have a c1 level of english you will be able to understand a wide range of long texts long articles.
# result2:
# ...
#                                          "it's a near native level of English "
#                                          "and it's equivalent to the Cambridge "
#                                          'English proficiency exam and the '
#                                          'IELTS level 8 to 9 not too many '
#                                          'people prepare these exams because '
#                                          'it really is an exceptionally high '
#                                          'level if you have a C2 level of '
#                                          'English you can understand and read '
#                                          'almost anything'}],
#     'final': True}
# audio-chunks/chunk48.wav : The highest level of the common european framework of reference for languages is c2 and c2 is proficient it's a near native level of english and it's equivalent to the cambridge english proficiency exam and the ions level 8 to 9 not too many people prepare these exams cuz it really is an exceptionally high level if you have a c2 level of english you can understand and read almost anything.
# result2:
# {   'alternative': [   {'confidence': 0.97219545, 'transcript': 'easil'},
#                        {'transcript': 'easily'},
#                        {'transcript': 'Easley'}],
#     'final': True}
# audio-chunks/chunk49.wav : Easil.
# result2:
# {   'alternative': [   {   'confidence': 0.97205317,
#                            'transcript': 'you can read or hear English from a '
#                                          'variety of sources TV radio movies '
#                                          'and summarize it into a very '
#                                          'coherent presentation you can '
#                                          'express yourself spontaneously'},
#                        {   'transcript': 'you can read or hear English from a '
#                                          'variety of sauces TV radio movies '
#                                          'and summarize it into a very '
#                                          'coherent presentation you can '
#                                          'express yourself spontaneously'},
#                        {   'transcript': 'you can read or hear English from a '
#                                          'variety of sources TV radio movies '
#                                          'and summarize it into a very '
#                                          'coherent presentation you can '
#                                          'express yourselves spontaneously'}],
#     'final': True}
# audio-chunks/chunk50.wav : You can read or hear english from a variety of sources tv radio movies and summarize it into a very coherent presentation you can express yourself spontaneously.
# result2:
# {   'alternative': [   {   'confidence': 0.97219545,
#                            'transcript': 'very fluently and not making'}],
#     'final': True}
# audio-chunks/chunk51.wav : Very fluently and not making.
# result2:
# {   'alternative': [   {   'confidence': 0.96972144,
#                            'transcript': 'almost any mistakes and even when '
#                                          "you're talking about complex things "
#                                          'you can really make small '
#                                          'differences to what you say just to '
#                                          'put emphasis on slightly different '
#                                          'parts of the sentence this is '
#                                          'defined as differentiating finite '
#                                          'shades of meaning so making small '
#                                          'changes to the words you use or the '
#                                          'grammar you use to give a slightly '
#                                          'different meaning so I hope this '
#                                          'helps you evaluate your own level of '
#                                          'English'},
#                        {   'transcript': 'almost any mistakes and even when '
#                                          "you're talking about complex things "
#                                          'you can really make small '
#                                          'differences to what you say just to '
#                                          'put emphasis on slightly different '
#                                          'parts of the sentence this is '
#                                          'defined as differentiating finite '
#                                          'shades of meaning so making small '
#                                          'changes to the words you use or the '
#                                          'grammar you use to give us slightly '
#                                          'different meaning so I hope this '
#                                          'helps you evaluate your own level of '
#                                          'English'},
#                        {   'transcript': 'almost any mistakes and even when '
#                                          "you're talking about complex things "
#                                          'you can really make small '
#                                          'differences to what you say just to '
#                                          'put emphasis on slightly different '
#                                          'parts of the sentence this is '
#                                          'defined as differentiating finite '
#                                          'shades of meaning so making small '
#                                          'changes to the words you use or the '
#                                          'grammer you use to give a slightly '
#                                          'different meaning so I hope this '
#                                          'helps you evaluate your own level of '
#                                          'English'}],
#     'final': True}
# audio-chunks/chunk52.wav : Almost any mistakes and even when you're talking about complex things you can really make small differences to what you say just to put emphasis on slightly different parts of the sentence this is defined as differentiating finite shades of meaning so making small changes to the words you use or the grammar you use to give a slightly different meaning so i hope this helps you evaluate your own level of english.
# result2:
# {   'alternative': [   {   'confidence': 0.97062302,
#                            'transcript': 'tell me in the comments what level '
#                                          'you have and also what level you are '
#                                          'working towards what level of '
#                                          'English you would really like to '
#                                          'have as I said before on this '
#                                          'YouTube channel and in my business I '
#                                          'help students take their English '
#                                          'from an intermediate level to a C1 '
#                                          'level of English'},
#                        {   'transcript': 'tell me in the comments what level '
#                                          'you have and also what level you are '
#                                          'working towards what level of '
#                                          'English you would really like to '
#                                          'have as I said before on this '
#                                          'YouTube channel and in my business I '
#                                          'help students take their English '
#                                          'from an intermediate level to a c-1 '
#                                          'level of English'},
#                        {   'transcript': 'tell me in the comments what level '
#                                          'you have and also what level you are '
#                                          'working towards what level of '
#                                          'English you would really like to '
#                                          'have as I said before on this '
#                                          'YouTube channel and in my business I '
#                                          'help students take their English '
#                                          'from it intermediate level to a C1 '
#                                          'level of English'},
#                        {   'transcript': 'tell me in the comments what level '
#                                          'you have and also what level you are '
#                                          'working towards what level of '
#                                          'English you would really like to '
#                                          'have as I said before on this '
#                                          'YouTube channel and in my business I '
#                                          'help students take their English '
#                                          'from an intermediate level to a c '
#                                          'one level of English'},
#                        {   'transcript': 'tell me in the comments what level '
#                                          'you have and also what level you are '
#                                          'working towards what level of '
#                                          'English you would really like to '
#                                          'have as I said before on this '
#                                          'YouTube channel and in my business I '
#                                          'help students take their English '
#                                          'from it intermediate level to a c-1 '
#                                          'level of English'}],
#     'final': True}
# audio-chunks/chunk53.wav : Tell me in the comments what level you have and also what level you are working towards what level of english you would really like to have as i said before on this youtube channel and in my business i help students take their english from an intermediate level to a c1 level of english.
# result2:
# {   'alternative': [   {   'confidence': 0.97217125,
#                            'transcript': "that's what you want then subscribe "
#                                          'to my Channel for free weekly '
#                                          'lessons on English pronunciation and '
#                                          'grammar and check out the '
#                                          'description for other ways that you '
#                                          'can advance your English with me'},
#                        {   'transcript': "that's what you want then subscribe "
#                                          'to my Channel for free weekly '
#                                          'lessons on English pronunciation and '
#                                          'grammar and check out the '
#                                          'description for other ways that you '
#                                          'can add Advance your English with '
#                                          'me'}],
#     'final': True}
# audio-chunks/chunk54.wav : That's what you want then subscribe to my channel for free weekly lessons on english pronunciation and grammar and check out the description for other ways that you can advance your english with me.
# result2:
# {   'alternative': [   {   'confidence': 0.97219557,
#                            'transcript': "thanks for being here and I'll see "
#                                          'you in the next lesson'}],
#     'final': True}
# audio-chunks/chunk55.wav : Thanks for being here and i'll see you in the next lesson.
# result2:
# []
# Error:
#
# Texto EN: My name is greg and in this video i'm going to teach you how you can evaluate your own level of english according to the common european framework of reference for languages. So let's go. Basically the common european framework of reference for languages is divided into six different levels they are a1 a2 b1 b2. C1 and c2 now we can think of the a levels to be beginner levels. The b levels to be intermediate levels. On the sea levels to be advanced levels we're going to look at each of these levels so that you can evaluate your own level of english this will enable you to know which exam you should be preparing and it will also enable you to give your future employers and idea of what english level you currently have and after watching this video i want you to write a comment telling me what level you have. And what level of english you want. A1 is the beginner level of english and this is the equivalent to the cambridge young learners exam called movers you have an a1 level of english if you can understand and use very basic expressions in english you can introduce yourself and ask questions about personal details of other people and you can interact with other people if they speak slowly. And if they are prepared to really modify their language and make an effort to be understood by you. The a2 level can be described as elementary. And this is the equivalent to the cambridge young learners exam called flyers now if you have an a2 level of english you can understand. Frequently used expressions about common topics such as shopping travel work and local geography like your town or where you live. You can describe in simple terms about your background about your life and about your environment about where you live. But again in simple terms. Now most people i deal with have an intermediate level of english and in my business i help take them to an advanced level of english. Intermediate is divided into two parts b1 and b2 b1 is the equivalent to the cambridge preliminary exam. Pet pilots level 4 and the toefl score between 57 and 86 you have a b1 level if you can understand points related to family. Elijah and school. And if you can deal with most travel situations. Like going to the airport going to restaurants checking in at a hotel. Typical travel situations you can write text about topics of personal interest and you can describe both in spoken english and written english experiences events dreams ambitions and also give brief opinions on things and talk about your plans if you can do all that in english you have a b1 level. B2 is considered to be upper intermediate and this is the equivalent of the cambridge first certificate of english. I don't level five to six and a total score of between 87 and 109 b2 is usually the minimum requirement that companies ask for if english isn't an extremely important part of their job. You have a b2 level of english if you can understand the main ideas of a more technical text you will also be able to communicate spontaneously with a native speaker without too much effort for you. Or without too much effort for the native speaker to understand you and spontaneously means just reacting naturally to the questions they asked you without having to stop and really think about how to construct the sentence or how to find the correct piece of vocabulary you will also be able to write a text on a wide variety of subjects in a wide variety of styles. Giving your opinions and pointing out the advantages and disadvantages of common topics. We then move on to the advanced levels of english c1 and c2 now in my experience c1 is a level of english that most students want to reach and normally when companies ask for a high level of english they're asking for a c1 level this is the equivalent of the cambridge advanced exam i don't level seven a total score of between 110 and 120 and atomic score of 880. If you have a c1 level of english you will be able to understand a wide range of long texts l ...

# %%
# PT
path = "audioPT.wav"
print("\nTexto PT:", get_large_audio_transcription(path, "pt-PT"))
# Out:
# result2:
# {   'alternative': [   {   'confidence': 0.78516257,
#                            'transcript': 'Hoje vamos falar como devemos '
#                                          'planear financeiramente o novo ano '
#                                          'Olá a todos o meu nome é Ariana '
#                                          'Nunes e este é o canal renda maior '
#                                          'este vídeo para por favor deixarem '
#                                          'ficar o seu gosto'},
#                        {   'transcript': 'Hoje vamos falar como devemos '
#                                          'planear financeiramente o novo ano '
#                                          'Olá Todos o meu nome é Ariana Nunes '
#                                          'e este é o canal renda maior este '
#                                          'vídeo para por favor deixarem ficar '
#                                          'o seu gosto'},
#                        {   'transcript': 'Hoje vamos falar como devemos '
#                                          'planear financeiramente o novo ano '
#                                          'Olá a todos o meu nome é Ariana '
#                                          'Nunes e este é o canal renda maior '
#                                          'este vídeo para por favor deixarem '
#                                          'de ficar o seu gosto'},
#                        {   'transcript': 'Hoje vamos falar como devemos '
#                                          'planear financeiramente o novo ano '
#                                          'Olá Todos o meu nome é Ariana Nunes '
#                                          'e este é o canal renda maior este '
#                                          'vídeo para por favor deixarem de '
#                                          'ficar o seu gosto'},
#                        {   'transcript': 'Hoje vamos falar como devemos '
#                                          'planear financeiramente o novo ano '
#                                          'Olá a todos o meu nome é Ariana '
#                                          'Nunes e este é o canal renda maior '
#                                          'este vídeo para por favor deixarem '
#                                          'ficar o seu'}],
#     'final': True}
# audio-chunks/chunk1.wav : Hoje vamos falar como devemos planear financeiramente o novo ano olá a todos o meu nome é ariana nunes e este é o canal renda maior este vídeo para por favor deixarem ficar o seu gosto.
# result2:
# {   'alternative': [   {   'confidence': 0.80095422,
#                            'transcript': 'em cima tudo para quem ainda não é '
#                                          'inscrito por favor clique no botão '
#                                          'que está aqui embaixo e faça parte '
#                                          'deste projeto'},
#                        {   'transcript': 'em cima tudo para quem ainda não é '
#                                          'inscrito por favor clique no botão '
#                                          'que está aqui em baixo e faça parte '
#                                          'deste projeto'},
#                        {   'transcript': 'em cima tudo para quem ainda não é '
#                                          'inscrito por favor clique no botão '
#                                          'que está aqui embaixo e faça parte '
#                                          'desse projeto'},
#                        {   'transcript': 'em cima tudo para quem ainda não é '
#                                          'inscrito por favor clique no botão '
#                                          'que está aqui embaixo e faça parte '
#                                          'deste proje'}],
#     'final': True}
# audio-chunks/chunk2.wav : Em cima tudo para quem ainda não é inscrito por favor clique no botão que está aqui embaixo e faça parte deste projeto.
# result2:
# {   'alternative': [   {   'confidence': 0.81246638,
#                            'transcript': 'porque se fosse porque no gesto '
#                                          'significa muito para mim e ficarei '
#                                          'extremamente agradecida por ajudarem '
#                                          'o canal renda maior a chegar mais '
#                                          'longe Hoje vamos falar da '
#                                          'importância de ter um plano '
#                                          'financeiro para este novo ano tendo '
#                                          'em conta que começou o mesmo e nós '
#                                          'temos que ter metas definidas'},
#                        {   'transcript': 'porque se fosse porque no gesto '
#                                          'significa muito para mim e ficarei '
#                                          'extremamente agradecida por ajudarem '
#                                          'o canal renda maior a chegar mais '
#                                          'longe Hoje vamos falar da '
#                                          'importância de ter um plano '
#                                          'financeiro para este novo ano tendo '
#                                          'em conta que começou mesmo e nós '
#                                          'temos que ter metas definidas'},
#                        {   'transcript': 'porque se fosse porque no gesto '
#                                          'significa muito para mim e ficarei '
#                                          'extremamente agradecida por ajudarem '
#                                          'o canal renda maior a chegar mais '
#                                          'longe Hoje vamos falar da '
#                                          'importância de ter um plano '
#                                          'financeiro para este novo ano tendo '
#                                          'em conta que começou o mesmo e nós '
#                                          'temos que ter metas defin'},
#                        {   'transcript': 'porque se fosse porque no gesto '
#                                          'significa muito para mim e ficarei '
#                                          'extremamente agradecida por ajudarem '
#                                          'o canal renda maior a chegar mais '
#                                          'longe Hoje vamos falar da '
#                                          'importância de ter um plano '
#                                          'financeiro para este novo ano tendo '
#                                          'em conta que começou mesmo e nós '
#                                          'temos que ter metas defin'}],
#     'final': True}
# audio-chunks/chunk3.wav : Porque se fosse porque no gesto significa muito para mim e ficarei extremamente agradecida por ajudarem o canal renda maior a chegar mais longe hoje vamos falar da importância de ter um plano financeiro para este novo ano tendo em conta que começou o mesmo e nós temos que ter metas definidas.
# result2:
# {   'alternative': [   {   'confidence': 0.81458282,
#                            'transcript': 'todos os anos a primeira coisa que '
#                                          'eu faço no início do ano é definir '
#                                          'qual é a média que eu quero ter em '
#                                          'termos financeiros no final do ano '
#                                          'Isto é a 31 de dezembro isso '
#                                          'significa neste caso ter também '
#                                          'atenção obviamente ao meu orçamento '
#                                          'à minha poupança e claro aos meus '
#                                          'rendimentos podemos todos comer as '
#                                          '12 passas e pedir uma série de '
#                                          'desejos inclusive poder neste caso '
#                                          'enriquecer durante este próximo ano '
#                                          'mas se não fizemos nada '
#                                          'provavelmente também não irá '
#                                          'acontecer nada'},
#                        {   'transcript': 'todos os anos a primeira coisa que '
#                                          'eu faço no início do ano é definir '
#                                          'qual é a meta que eu quero ter em '
#                                          'termos financeiros no final do ano '
#                                          'Isto é a 31 de dezembro isso '
#                                          'significa neste caso ter também '
#                                          'atenção obviamente ao meu orçamento '
#                                          'à minha poupança e claro aos meus '
#                                          'rendimentos podemos todos comer as '
#                                          '12 passas e pedir uma série de '
#                                          'desejos inclusive poder neste caso '
#                                          'enriquecer durante este próximo ano '
#                                          'mas se não fizemos nada '
#                                          'provavelmente também não irá '
#                                          'acontecer nada'},
#                        {   'transcript': 'todos os anos a primeira coisa que '
#                                          'eu faço no início do ano é definir '
#                                          'qual é a média que eu quero ter em '
#                                          'termos financeiros no final do ano '
#                                          'Isto é a 31 de dezembro isso '
#                                          'significa neste caso ter também '
#                                          'atenção obviamente ao meu orçamento '
#                                          'à minha poupança e claro aos meus '
#                                          'rendimentos podemos todos comer as '
#                                          '12 passas e pedir uma série de '
#                                          'desejos inclusive poder neste caso '
#                                          'enriquecer durante este próximo ano '
#                                          'mas se não fizermos nada '
#                                          'provavelmente também não irá '
#                                          'acontecer nada'},
#                        {   'transcript': 'todos os anos a primeira coisa que '
#                                          'eu faço no início do ano é definir '
#                                          'qual é a média que eu quero ter em '
#                                          'termos financeiros no final do ano '
#                                          'Isto é a 31 de dezembro isso '
#                                          'significa neste caso ter também '
#                                          'atenção obviamente ao meu orçamento '
#                                          'à minha poupança e claro aos meus '
#                                          'rendimentos podemos todos comer as '
#                                          '12 passas e pedir uma série de '
#                                          'desejos inclusive poder neste caso '
#                                          'enriquecer durante este próximo ano '
#                                          'mas se não fizemos nada '
#                                          'provavelmente também não irá '
#                                          'acontecer'}],
#     'final': True}
# audio-chunks/chunk4.wav : Todos os anos a primeira coisa que eu faço no início do ano é definir qual é a média que eu quero ter em termos financeiros no final do ano isto é a 31 de dezembro isso significa neste caso ter também atenção obviamente ao meu orçamento à minha poupança e claro aos meus rendimentos podemos todos comer as 12 passas e pedir uma série de desejos inclusive poder neste caso enriquecer durante este próximo ano mas se não fizemos nada provavelmente também não irá acontecer nada.
# result2:
# {   'alternative': [   {   'confidence': 0.80050343,
#                            'transcript': 'e desta forma eu vou falar aqui '
#                                          'sobre algumas coisas que eu faço que '
#                                          'pode ajudar muita gente desse'},
#                        {   'transcript': 'e desta forma vou falar aqui sobre '
#                                          'algumas coisas que eu faço que pode '
#                                          'ajudar muita gente desse'},
#                        {   'transcript': 'e desta forma eu vou falar aqui '
#                                          'sobre algumas coisas que eu faço que '
#                                          'pode ajudar muita gente desse lado'},
#                        {   'transcript': 'e desta forma vou falar aqui sobre '
#                                          'algumas coisas que eu faço que pode '
#                                          'ajudar muita gente desse lado'},
#                        {   'transcript': 'e desta forma vou falar aqui sobre '
#                                          'algumas coisas que eu faço que pode '
#                                          'ajudar muita gente deste'}],
#     'final': True}
# audio-chunks/chunk5.wav : E desta forma eu vou falar aqui sobre algumas coisas que eu faço que pode ajudar muita gente desse.
# result2:
# {   'alternative': [   {   'confidence': 0.80712318,
#                            'transcript': 'organizar finance'},
#                        {'transcript': 'organizar-se finance'},
#                        {'transcript': 'organizasse finance'}],
#     'final': True}
# audio-chunks/chunk6.wav : Organizar finance.
# result2:
# {   'alternative': [   {   'confidence': 0.80807281,
#                            'transcript': 'para regra financeira que maior '
#                                          'parte dos indicadores financeiros '
#                                          'falam nos livros e que comenta por '
#                                          'todos esses vídeos que vocês já '
#                                          'viram no YouTube tem a ver então com '
#                                          'o poupança e nomeadamente com o '
#                                          'valor que vocês devem poupar por '
#                                          'mês'},
#                        {   'transcript': 'para regra financeira que maior '
#                                          'parte dos indicadores financeiros '
#                                          'falam nos livros e que comenta por '
#                                          'todos esses vídeos que vocês já '
#                                          'viram no YouTube tem a ver então com '
#                                          'o poupança nomeadamente com o valor '
#                                          'que vocês devem poupar por mês'}],
#     'final': True}
# audio-chunks/chunk7.wav : Para regra financeira que maior parte dos indicadores financeiros falam nos livros e que comenta por todos esses vídeos que vocês já viram no youtube tem a ver então com o poupança e nomeadamente com o valor que vocês devem poupar por mês.
# result2:
# {   'alternative': [   {   'confidence': 0.80494595,
#                            'transcript': 'Lógico que se vemos mensalmente '
#                                          'aquilo que nós devemos fazer é '
#                                          'sempre tirar uma porcentagem desse '
#                                          'rendimento para nós próprio'},
#                        {   'transcript': 'Lógico que se vemos mensalmente '
#                                          'aquilo que nós devemos fazer é '
#                                          'sempre tirar uma percentagem desse '
#                                          'rendimento para nós próprio'},
#                        {   'transcript': 'Lógico que se vemos mensalmente '
#                                          'aquilo que nós devemos fazer é '
#                                          'sempre tirar uma porcentagem desse '
#                                          'rendimento para nós'},
#                        {   'transcript': 'Lógico que se vemos mensalmente '
#                                          'aquilo que nós devemos fazer é '
#                                          'sempre tirar uma percentagem desse '
#                                          'rendimento para nós'}],
#     'final': True}
# audio-chunks/chunk8.wav : Lógico que se vemos mensalmente aquilo que nós devemos fazer é sempre tirar uma porcentagem desse rendimento para nós próprio.
# result2:
# {   'alternative': [   {   'confidence': 0.81231648,
#                            'transcript': 'desta forma o que os manuais dizem é '
#                                          'que será no mínimo 10%'},
#                        {   'transcript': 'que desta forma o que os manuais '
#                                          'dizem é que será no mínimo 10%'}],
#     'final': True}
# audio-chunks/chunk9.wav : Desta forma o que os manuais dizem é que será no mínimo 10%.
# result2:
# {   'alternative': [   {   'confidence': 0.81354624,
#                            'transcript': 'da minha Ótica 10% não serve para '
#                                          'muito é pouco mais do que um salário '
#                                          'extra no final do ano e já que temos '
#                                          'também o décimo terceiro mês e o '
#                                          'suficiente de férias porque não '
#                                          'também contar com esses subsídios '
#                                          'para podermos aqui ampliar essa taxa '
#                                          'de poupança na minha Ótica acho que '
#                                          'devemos sempre tentar fazer um '
#                                          'esforço maior e pelo menos poupar '
#                                          '15% do nosso rendimento mensal e 15% '
#                                          'também de cada subsídio Que nós '
#                                          'tínhamos em terceiro lugar acho que '
#                                          'é muito importante perceber em que é '
#                                          'necessário termos uma renda extra '
#                                          'seja ela ativa ou passiva seja algo '
#                                          'que vocês conseguem ter por exemplo '
#                                          'criaram um e-book'},
#                        {   'transcript': 'da minha Ótica 10% não serve para '
#                                          'muito é pouco mais do que um salário '
#                                          'extra no final do ano e já que temos '
#                                          'também o décimo terceiro mês e o '
#                                          'suficiente de férias porque não '
#                                          'também contar com esses subsídios '
#                                          'para podermos aqui ampliar essa taxa '
#                                          'de poupança na minha Ótica acho que '
#                                          'devemos sempre tentar fazer um '
#                                          'esforço maior e pelo menos poupar '
#                                          '15% do nosso rendimento mensal e 15% '
#                                          'também de cada subsídio Que nós '
#                                          'tínhamos em terceiro lugar acho que '
#                                          'é muito importante perceber em que é '
#                                          'necessário termos uma renda extra '
#                                          'seja ela ativa ou passiva seja algo '
#                                          'que vocês conseguem ter porque por '
#                                          'exemplo criaram um e-book'},
#                        {   'transcript': 'da minha Ótica 10% não serve para '
#                                          'muito é pouco mais do que um salário '
#                                          'extra no final do ano e já que temos '
#                                          'também o décimo terceiro mês e o '
#                                          'suficiente de férias porque não '
#                                          'também contar com esses subsídios '
#                                          'para podermos aqui ampliar essa taxa '
#                                          'de poupança na minha Ótica acho que '
#                                          'devemos sempre tentar fazer um '
#                                          'esforço maior e pelo menos poupar '
#                                          '15% do nosso rendimento mensal e 15% '
#                                          'também de cada subsídio Que nós '
#                                          'tínhamos em terceiro lugar acho que '
#                                          'é muito importante perceber em que é '
#                                          'necessário termos uma renda extra '
#                                          'seja ela ativa ou passiva seja algo '
#                                          'que vocês conseguem ter porque por '
#                                          'exemplo criaram um e-'},
#                        {   'transcript': 'da minha Ótica 10% não serve para '
#                                          'muito é pouco mais do que um salário '
#                                          'extra no final do ano e já que temos '
#                                          'também o décimo terceiro mês e o '
#                                          'suficiente de férias porque não '
#                                          'também contar com esses subsídios '
#                                          'para podermos aqui ampliar essa taxa '
#                                          'de poupança na minha Ótica acho que '
#                                          'devemos sempre tentar fazer um '
#                                          'esforço maior e pelo menos poupar '
#                                          '15% do nosso rendimento mensal e 15% '
#                                          'também de cada subsídio Que nós '
#                                          'tínhamos em terceiro lugar acho que '
#                                          'é muito importante perceber em que é '
#                                          'necessário termos uma renda extra '
#                                          'seja ela ativa ou passiva seja algo '
#                                          'que vocês conseguem ter porque por '
#                                          'exemplo criaram ebook'},
#                        {   'transcript': 'da minha Ótica 10% não serve para '
#                                          'muito é pouco mais do que um salário '
#                                          'extra no final do ano e já que temos '
#                                          'também o décimo terceiro mês e o '
#                                          'suficiente de férias porque não '
#                                          'também contar com esses subsídios '
#                                          'para podermos aqui ampliar essa taxa '
#                                          'de poupança na minha Ótica acho que '
#                                          'devemos sempre tentar fazer um '
#                                          'esforço maior e pelo menos poupar '
#                                          '15% do nosso rendimento mensal e 15% '
#                                          'também de cada subsídio Que nós '
#                                          'tínhamos em terceiro lugar acho que '
#                                          'é muito importante perceber em que é '
#                                          'necessário termos uma renda extra '
#                                          'seja ela ativa ou passiva seja algo '
#                                          'que vocês conseguem ter porque por '
#                                          'exemplo criaram e-book'}],
#     'final': True}
# audio-chunks/chunk10.wav : Da minha ótica 10% não serve para muito é pouco mais do que um salário extra no final do ano e já que temos também o décimo terceiro mês e o suficiente de férias porque não também contar com esses subsídios para podermos aqui ampliar essa taxa de poupança na minha ótica acho que devemos sempre tentar fazer um esforço maior e pelo menos poupar 15% do nosso rendimento mensal e 15% também de cada subsídio que nós tínhamos em terceiro lugar acho que é muito importante perceber em que é necessário termos uma renda extra seja ela ativa ou passiva seja algo que vocês conseguem ter por exemplo criaram um e-book.
# result2:
# {   'alternative': [   {   'confidence': 0.81071419,
#                            'transcript': 'alguma das vossas Skills das vossas '
#                                          'competências e conseguiram vender o '
#                                          'mesmo sejam por exemplo ativamente '
#                                          'ajudarem no restaurante A Servir ou '
#                                          'fazer qualquer outra coisa que vos '
#                                          'permite a ganhar dinheiro e desta '
#                                          'forma ter uma renda extra vai-vos '
#                                          'aumentar a vossa capacidade de '
#                                          'poupança isso pode fazer toda a '
#                                          'diferença no final do mês'},
#                        {   'transcript': 'alguma das vossas Skills das vossas '
#                                          'competências e conseguiram vender o '
#                                          'mesmo sejam por exemplo ativamente '
#                                          'ajudarem no restaurante A Servir ou '
#                                          'fazer qualquer outra coisa que vos '
#                                          'permite a ganhar dinheiro e desta '
#                                          'forma ter uma renda extra vai-vos '
#                                          'aumentar a vossa capacidade de '
#                                          'poupança isso pode fazer toda a '
#                                          'diferença no final do'},
#                        {   'transcript': 'alguma das vossas Skills das vossas '
#                                          'competências e conseguiram vender o '
#                                          'mesmo sejam por exemplo ativamente '
#                                          'ajudarem no restaurante A Servir ou '
#                                          'fazer qualquer outra coisa que vos '
#                                          'permite a ganhar dinheiro e desta '
#                                          'forma ter uma renda extra vai-vos '
#                                          'aumentar a vossa capacidade de '
#                                          'poupança e isso pode fazer toda a '
#                                          'diferença no final do mês'},
#                        {   'transcript': 'alguma das vossas Skills das vossas '
#                                          'competências e conseguiram vender o '
#                                          'mesmo sejam por exemplo ativamente '
#                                          'ajudarem no restaurante A Servir ou '
#                                          'fazer qualquer outra coisa que vos '
#                                          'permite a ganhar dinheiro e desta '
#                                          'forma ter uma renda extra vai-vos '
#                                          'aumentar a vossa capacidade de '
#                                          'poupança e isso pode fazer toda a '
#                                          'diferença no final do'}],
#     'final': True}
# audio-chunks/chunk11.wav : Alguma das vossas skills das vossas competências e conseguiram vender o mesmo sejam por exemplo ativamente ajudarem no restaurante a servir ou fazer qualquer outra coisa que vos permite a ganhar dinheiro e desta forma ter uma renda extra vai-vos aumentar a vossa capacidade de poupança isso pode fazer toda a diferença no final do mês.
# result2:
# {   'alternative': [   {   'confidence': 0.79764599,
#                            'transcript': 'energia está então neste caso no '
#                                          'Mult rendimento não ter só o salário '
#                                          'mas sem ter outros negócios outras '
#                                          'atividades'},
#                        {   'transcript': 'energia está então neste caso no '
#                                          'Mult rendimento não ter só o salário '
#                                          'mas sim ter outros negócios outras '
#                                          'atividades'}],
#     'final': True}
# audio-chunks/chunk12.wav : Energia está então neste caso no mult rendimento não ter só o salário mas sem ter outros negócios outras atividades.
# result2:
# {   'alternative': [   {   'confidence': 0.72231752,
#                            'transcript': 'vos posso ajudar dinheiro '
#                                          'mensalmente E com isso consigam '
#                                          'então aumentar a vossa poupança '
#                                          'anual'},
#                        {   'transcript': 'vos posso ajudar dinheiro '
#                                          'mensalmente E com isso consigam '
#                                          'então aumentar o vosso população no'},
#                        {   'transcript': 'vos posso ajudar dinheiro '
#                                          'mensalmente E com isso consigam '
#                                          'então aumentar o vosso população'},
#                        {   'transcript': 'vos posso ajudar dinheiro '
#                                          'mensalmente E com isso consigam '
#                                          'então aumentar o vosso população '
#                                          'para pensar no'}],
#     'final': True}
# audio-chunks/chunk13.wav : Vos posso ajudar dinheiro mensalmente e com isso consigam então aumentar a vossa poupança anual.
# result2:
# {   'alternative': [   {   'confidence': 0.8154785,
#                            'transcript': 'desta forma para poderem realizar os '
#                                          'vossos objetivos mas também ter um '
#                                          'conforto financeiro porque no final '
#                                          'do ano se vocês tiverem mais 1000 '
#                                          '3000 5000 10.000 de acordo com os '
#                                          'vossos rendimentos e com a vossa '
#                                          'capacidade de poupança isso vai se '
#                                          'fazer vocês pessoas mais seguras e '
#                                          'mais tranquilas em relação à Vida '
#                                          'Porque infelizmente as coisas '
#                                          'acontecem e nós temos que estar '
#                                          'preparados lembre-se que não teremos '
#                                          'os mesmos rendimentos os mesmos '
#                                          'objetivos e despesas a mesma '
#                                          'capacidade de poupança e por isso é '
#                                          'importante perceber que não se devem '
#                                          'Comparar as outras pessoas porque '
#                                          'muitas vezes é impossível comparar'},
#                        {   'transcript': 'desta forma para poderem realizar os '
#                                          'vossos objetivos mas também ter um '
#                                          'conforto financeiro porque no final '
#                                          'do ano se vocês tiverem mais 1000 '
#                                          '3000 5000 10.000 de acordo com os '
#                                          'vossos rendimentos e com a vossa '
#                                          'capacidade de poupança isso vai se '
#                                          'fazer vocês pessoas mais seguras e '
#                                          'mais tranquilas em relação à Vida '
#                                          'Porque infelizmente as coisas '
#                                          'acontecem e nós temos que estar '
#                                          'preparados lembre-se que não teremos '
#                                          'os mesmos rendimentos os mesmos '
#                                          'objetivos e despesas a mesma '
#                                          'capacidade de poupança e por isso é '
#                                          'importante perceber que não se devem '
#                                          'comparar às outras pessoas porque '
#                                          'muitas vezes é impossível comparar'},
#                        {   'transcript': 'desta forma para poderem realizar os '
#                                          'vossos objetivos mas também ter um '
#                                          'conforto financeiro porque no final '
#                                          'do ano se vocês tiverem mais 1000 '
#                                          '3000 5000 10.000 de acordo com os '
#                                          'vossos rendimentos e com a vossa '
#                                          'capacidade de poupança isso vai se '
#                                          'fazer vocês pessoas mais seguras e '
#                                          'mais tranquilas em relação à Vida '
#                                          'Porque infelizmente as coisas '
#                                          'acontecem e nós temos que estar '
#                                          'preparados lembre-se que não teremos '
#                                          'os mesmos rendimentos os mesmos '
#                                          'objectivos e despesas a mesma '
#                                          'capacidade de poupança e por isso é '
#                                          'importante perceber que não se devem '
#                                          'comparar às outras pessoas porque '
#                                          'muitas vezes é impossível comparar'}],
#     'final': True}
# audio-chunks/chunk14.wav : Desta forma para poderem realizar os vossos objetivos mas também ter um conforto financeiro porque no final do ano se vocês tiverem mais 1000 3000 5000 10.000 de acordo com os vossos rendimentos e com a vossa capacidade de poupança isso vai se fazer vocês pessoas mais seguras e mais tranquilas em relação à vida porque infelizmente as coisas acontecem e nós temos que estar preparados lembre-se que não teremos os mesmos rendimentos os mesmos objetivos e despesas a mesma capacidade de poupança e por isso é importante perceber que não se devem comparar as outras pessoas porque muitas vezes é impossível comparar.
# result2:
# {   'alternative': [   {   'confidence': 0.82141501,
#                            'transcript': 'do coqueiro das formas vocês devem '
#                                          'sempre pensar que se alguém consegue '
#                                          'alcançar Algum objetivo Como fazer '
#                                          'uma viagem ou constantemente estar a '
#                                          'ir a restaurantes não tá fora não '
#                                          'significa que aquela pessoa esteja a '
#                                          'fazer uma matização financeira '
#                                          'simplesmente poderá ter mais renda '
#                                          'extra poderá receber mais poderá '
#                                          'fazer outra coisa diferente de '
#                                          'vocês'},
#                        {   'transcript': 'do coqueiro das formas vocês devem '
#                                          'sempre pensar que se alguém consegue '
#                                          'alcançar Algum objetivo Como fazer '
#                                          'uma viagem ou constantemente estar a '
#                                          'ir a restaurantes não tá fora não '
#                                          'significa que aquela pessoa esteja a '
#                                          'fazer uma matização financeira '
#                                          'simplesmente poderá ter mais render '
#                                          'Extra poderá receber mais poderá '
#                                          'fazer outra coisa diferente de '
#                                          'vocês'}],
#     'final': True}
# audio-chunks/chunk15.wav : Do coqueiro das formas vocês devem sempre pensar que se alguém consegue alcançar algum objetivo como fazer uma viagem ou constantemente estar a ir a restaurantes não tá fora não significa que aquela pessoa esteja a fazer uma matização financeira simplesmente poderá ter mais renda extra poderá receber mais poderá fazer outra coisa diferente de vocês.
# result2:
# {   'alternative': [   {   'confidence': 0.81259006,
#                            'transcript': 'muitas vezes capacitamos através do '
#                                          'estudo através da realização '
#                                          'profissional através efetivamente de '
#                                          'mais trabalho conseguimos muitas '
#                                          'vezes adquir'},
#                        {   'transcript': 'muitas vezes capacitarmos através do '
#                                          'estudo através da realização '
#                                          'profissional através efetivamente de '
#                                          'mais trabalho conseguimos muitas '
#                                          'vezes adquir'},
#                        {   'transcript': 'muitas vezes capacitamos através do '
#                                          'estudo através da realização '
#                                          'profissional através efetivamente de '
#                                          'mais trabalho conseguimos muitas '
#                                          'vezes adquire'},
#                        {   'transcript': 'muitas vezes capacitamos através do '
#                                          'estudo através da realização '
#                                          'profissional através efetivamente de '
#                                          'mais trabalho conseguimos muitas '
#                                          'vezes adqui'}],
#     'final': True}
# audio-chunks/chunk16.wav : Muitas vezes capacitamos através do estudo através da realização profissional através efetivamente de mais trabalho conseguimos muitas vezes adquir.
# result2:
# {   'alternative': [   {   'confidence': 0.76743186,
#                            'transcript': 'o valor superior em termos de '
#                                          'rendimento'},
#                        {   'transcript': 'um valor superior em termos de '
#                                          'rendimento'}],
#     'final': True}
# audio-chunks/chunk17.wav : O valor superior em termos de rendimento.
# result2:
# {   'alternative': [   {   'confidence': 0.80346805,
#                            'transcript': 'Com certeza que devem sempre apostar '
#                                          'no vosso formação porque com '
#                                          'competência'},
#                        {   'transcript': 'Com certeza que devem sempre apostar '
#                                          'no vossa formação porque com '
#                                          'competência'},
#                        {   'transcript': 'Com certeza que devem sempre apostar '
#                                          'no vosso formação porque com '
#                                          'competências'},
#                        {   'transcript': 'Com certeza que devem sempre apostar '
#                                          'no vossa formação porque com '
#                                          'competências'}],
#     'final': True}
# audio-chunks/chunk18.wav : Com certeza que devem sempre apostar no vosso formação porque com competência.
# result2:
# {   'alternative': [   {   'confidence': 0.81341803,
#                            'transcript': 'normalmente os próprios salários '
#                                          'serão melhores como estamos no '
#                                          'início do ano devemos já começar a '
#                                          'tomar as nossas medidas para comando '
#                                          'seja diferente dos anos anteriores e '
#                                          'que este ano pelo menos '
#                                          'financeiramente sejam sucesso e por '
#                                          'isso aqui embaixo na descrição vocês '
#                                          'vão ter um link para poderem '
#                                          'descarregar gratuitamente'},
#                        {   'transcript': 'normalmente os próprios salários '
#                                          'serão melhores como estamos no '
#                                          'início do ano devemos já começar a '
#                                          'tomar as nossas medidas para comando '
#                                          'seja diferente dos anos anteriores e '
#                                          'que este ano pelo menos '
#                                          'financeiramente sejam sucesso e por '
#                                          'isso aqui em baixo na descrição '
#                                          'vocês vão ter um link para poderem '
#                                          'descarregar gratuitamente'},
#                        {   'transcript': 'normalmente os próprios salários '
#                                          'serão melhores como estamos no '
#                                          'início do ano devemos já começar a '
#                                          'tomar as nossas medidas para comando '
#                                          'seja diferente dos anos anteriores e '
#                                          'que este ano pelo menos '
#                                          'financeiramente sejam sucesso e por '
#                                          'isso aqui embaixo na descrição vocês '
#                                          'vão ter um link para poderem '
#                                          'descarregar gratuita'},
#                        {   'transcript': 'normalmente os próprios salários '
#                                          'serão melhores como estamos no '
#                                          'início do ano devemos já começar a '
#                                          'tomar as nossas medidas para comando '
#                                          'seja diferente dos anos anteriores e '
#                                          'que este ano pelo menos '
#                                          'financeiramente sejam sucesso e por '
#                                          'isso aqui em baixo na descrição '
#                                          'vocês vão ter um link para poderem '
#                                          'descarregar gratuita'}],
#     'final': True}
# audio-chunks/chunk19.wav : Normalmente os próprios salários serão melhores como estamos no início do ano devemos já começar a tomar as nossas medidas para comando seja diferente dos anos anteriores e que este ano pelo menos financeiramente sejam sucesso e por isso aqui embaixo na descrição vocês vão ter um link para poderem descarregar gratuitamente.
# result2:
# {   'alternative': [   {   'confidence': 0.82141507,
#                            'transcript': 'o que eu construir para me organizar '
#                                          'mensalmente'},
#                        {   'transcript': 'o cheiro Excel que eu construir para '
#                                          'me organizar mensalmente'},
#                        {   'transcript': 'o cheiro Excel que eu construí para '
#                                          'me organizar mensalmente'},
#                        {   'transcript': 'o cheiro Excel que eu construir para '
#                                          'me organizar mensal'}],
#     'final': True}
# audio-chunks/chunk20.wav : O que eu construir para me organizar mensalmente.
# result2:
# {   'alternative': [   {   'confidence': 0.82141501,
#                            'transcript': 'em termos de despesas e do orçamento '
#                                          'familiares recordo que existem '
#                                          'Campos que são editáveis em que '
#                                          'vocês podem então colocar os vossos '
#                                          'valores e todas as outras células '
#                                          'estão protegidas para evitar que '
#                                          'vocês coloquem mais desculpas para '
#                                          'onde gastar dinheiro de forma de '
#                                          'vida'},
#                        {   'transcript': 'em termos de despesas e do orçamento '
#                                          'familiares recordo que existem '
#                                          'Campos que são editáveis em que '
#                                          'vocês podem então colocar os vossos '
#                                          'valores e todas as outras células '
#                                          'estão protegidas para evitar que '
#                                          'vocês coloquem mais desculpas para '
#                                          'onde gastar dinheiro de forma indiv'},
#                        {   'transcript': 'em termos de despesas e do orçamento '
#                                          'familiares recordo que existem '
#                                          'Campos que são editáveis em que '
#                                          'vocês podem então colocar os vossos '
#                                          'valores e todas as outras células '
#                                          'estão protegidas para evitar que '
#                                          'vocês coloquem mais desculpas para '
#                                          'onde gastar dinheiro de forma '
#                                          'indivíd'},
#                        {   'transcript': 'em termos de despesas e do orçamento '
#                                          'familiares recordo que existem '
#                                          'Campos que são editáveis em que '
#                                          'vocês podem então colocar os vossos '
#                                          'valores e todas as outras células '
#                                          'estão protegidas para evitar que '
#                                          'vocês coloquem mais desculpas para '
#                                          'onde gastar dinheiro de forma '
#                                          'indivídu'},
#                        {   'transcript': 'em termos de despesas e do orçamento '
# ...
#                                          'seria uma capacidade digamos assim '
#                                          'uma percentagem de 8% sobre o meu '
#                                          'rendimento sobre aquilo que eu '
#                                          'indiquei é que este mês que tinha'},
#                        {   'transcript': 'você me conta que eu só iria '
#                                          'investir no vender aos este mês que '
#                                          'seria uma capacidade digamos assim '
#                                          'uma percentagem de 8% sobre o meu '
#                                          'rendimento sobre aquilo que eu '
#                                          'indiquei é que este mês que tinha'},
#                        {   'transcript': 'você me conta que eu só iria '
#                                          'investir no vender aos este mês que '
#                                          'seria uma capacidade digamos assim '
#                                          'uma percentagem de 8% sobre o meu '
#                                          'rendimento sobre aquilo que eu '
#                                          'indiquei é que este mês tinha'}],
#     'final': True}
# audio-chunks/chunk43.wav : Você me conta que eu só iria investir no vender ou este mês que seria uma capacidade digamos assim uma percentagem de 8% sobre o meu rendimento sobre aquilo que eu indiquei é que este mês que tinha.
# result2:
# {   'alternative': [   {   'confidence': 0.73513913,
#                            'transcript': 'e isso você vai fazer devem então '
#                                          'colocar aqui todos os meses'},
#                        {   'transcript': 'e isso que vocês devem fazer devem '
#                                          'então colocar aqui todos os meses'}],
#     'final': True}
# audio-chunks/chunk44.wav : E isso você vai fazer devem então colocar aqui todos os meses.
# result2:
# {   'alternative': [   {   'confidence': 0.82141501,
#                            'transcript': 'Qual é Então o vosso mapa digamos '
#                                          'para o mês em relação aonde querem '
#                                          'chegar e este ficheiro ao fechei '
#                                          'muito simples muito fácil de '
#                                          'utilizar e que vocês conseguem assim '
#                                          'desta forma'},
#                        {   'transcript': 'Qual é Então o vosso mapa digamos '
#                                          'para o mês em relação aonde querem '
#                                          'chegar e este ficheiro ao fechei '
#                                          'muito simples muito fácil de '
#                                          'utilizar e que vocês conseguem sim '
#                                          'desta forma'}],
#     'final': True}
# audio-chunks/chunk45.wav : Qual é então o vosso mapa digamos para o mês em relação aonde querem chegar e este ficheiro ao fechei muito simples muito fácil de utilizar e que vocês conseguem assim desta forma.
# result2:
# {   'alternative': [   {   'confidence': 0.7924211,
#                            'transcript': 'colocar metas eu coloco metas '
#                                          'anuais'},
#                        {'transcript': 'colocar metas eu coloco metas anua'},
#                        {'transcript': 'colocar metros eu coloco metas anuais'},
#                        {'transcript': 'colocar metros eu coloco metas anua'}],
#     'final': True}
# audio-chunks/chunk46.wav : Colocar metas eu coloco metas anuais.
# result2:
# {   'alternative': [   {   'confidence': 0.80207056,
#                            'transcript': 'e desta forma de vida então pelos 12 '
#                                          'meses do ano quando vocês quiserem '
#                                          'colocar aqui então mais podem por '
#                                          'exemplo pensão subsídio podemos '
#                                          'colocar aquele subsídio de eh férias '
#                                          'ou subsídio'},
#                        {   'transcript': 'e desta forma de vida então pelos 12 '
#                                          'meses do ano quando vocês quiserem '
#                                          'colocar aqui então mais podem por '
#                                          'exemplo pensão subsídio e podemos '
#                                          'colocar aquele subsídio de eh férias '
#                                          'ou subsídio'}],
#     'final': True}
# audio-chunks/chunk47.wav : E desta forma de vida então pelos 12 meses do ano quando vocês quiserem colocar aqui então mais podem por exemplo pensão subsídio podemos colocar aquele subsídio de eh férias ou subsídio.
# result2:
# {   'alternative': [   {   'confidence': 0.8172254,
#                            'transcript': 'décimo terceiro mês não é de Natal '
#                                          'portanto podemos colocar aqui mais '
#                                          '950 e desta forma devem alocar '
#                                          'depois mais património podem colocar '
#                                          'aqui outros valores distribuir de '
#                                          'outra forma colocar aqui presentes'},
#                        {   'transcript': 'décimo terceiro mês não é de Natal '
#                                          'portanto podemos colocar aqui mais '
#                                          '950 e desta forma devem alocar '
#                                          'depois mais patrimônio podem colocar '
#                                          'aqui outros valores distribuir de '
#                                          'outra forma colocar aqui presentes'},
#                        {   'transcript': 'décimo terceiro mês não é de Natal '
#                                          'portanto podemos colocar aqui mais '
#                                          '950 e desta forma devem alocar '
#                                          'depois mais património podem colocar '
#                                          'aqui outros valores distribuir de '
#                                          'outra forma colocar aqui prese'}],
#     'final': True}
# audio-chunks/chunk48.wav : Décimo terceiro mês não é de natal portanto podemos colocar aqui mais 950 e desta forma devem alocar depois mais património podem colocar aqui outros valores distribuir de outra forma colocar aqui presentes.
# result2:
# {   'alternative': [   {   'confidence': 0.79747766,
#                            'transcript': 'fazer também aqui outro tipo de '
#                                          'distribuição que faça sentido para o '
#                                          'vosso estilo de'},
#                        {   'transcript': 'a fazer também aqui outro tipo de '
#                                          'distribuição que faça sentido para o '
#                                          'vosso estilo de'}],
#     'final': True}
# audio-chunks/chunk49.wav : Fazer também aqui outro tipo de distribuição que faça sentido para o vosso estilo de.
# result2:
# {   'alternative': [   {   'confidence': 0.82141501,
#                            'transcript': 'e daí aqui tu usar este cheiro para '
#                                          'poderem obter a máxima visão daquilo '
#                                          'que estão a fazer distribuir bem '
#                                          'todos os euros que entram como '
#                                          'rendimento'},
#                        {   'transcript': 'e daí aqui tu usar este cheiro para '
#                                          'poderem obter a máxima visão daquilo '
#                                          'que estão a fazer distribuir bem '
#                                          'todos os € que entram como '
#                                          'rendimento'}],
#     'final': True}
# audio-chunks/chunk50.wav : E daí aqui tu usar este cheiro para poderem obter a máxima visão daquilo que estão a fazer distribuir bem todos os euros que entram como rendimento.
# result2:
# {   'alternative': [   {   'confidence': 0.78734624,
#                            'transcript': 'e conseguir obviamente alcançar o '
#                                          'vosso objetivo financeiro para este'},
#                        {   'transcript': 'e conseguiram obviamente alcançar o '
#                                          'vosso objetivo financeiro para este'},
#                        {   'transcript': 'e conseguir obviamente alcançar o '
#                                          'vosso objetivo financeiro para '
#                                          'estar'}],
#     'final': True}
# audio-chunks/chunk51.wav : E conseguir obviamente alcançar o vosso objetivo financeiro para este.
# result2:
# {   'alternative': [   {   'confidence': 0.82141507,
#                            'transcript': 'se acharão valor este vídeo eu vou '
#                                          'pedir por favor'},
#                        {   'transcript': 'seu charol valor este vídeo eu vou '
#                                          'pedir por favor'}],
#     'final': True}
# audio-chunks/chunk52.wav : Se acharão valor este vídeo eu vou pedir por favor.
# result2:
# {   'alternative': [   {   'confidence': 0.74699771,
#                            'transcript': 'Mas mesmo por favor que deixem ficar '
#                                          'um'},
#                        {   'transcript': 'Mas mesmo por favor que deixa eu '
#                                          'ficar um'},
#                        {   'transcript': 'Mas mesmo por favor que deixam ficar '
#                                          'um'}],
#     'final': True}
# audio-chunks/chunk53.wav : Mas mesmo por favor que deixem ficar um.
# result2:
# {   'alternative': [   {   'confidence': 0.8100884,
#                            'transcript': 'e para quem não é inscrito subscreva '
#                                          'porque faz toda a diferença aqui no '
#                                          'projeto muito obrigada a todos pelo '
#                                          'vosso contributo já sabem da minha '
#                                          'parte eu espero-vos no próximo '
#                                          'vídeo'},
#                        {   'transcript': 'e para quem não é inscrito subscreva '
#                                          'porque faz toda a diferença aqui no '
#                                          'projeto muito obrigada a todos pelo '
#                                          'vosso contributo já sabem da minha '
#                                          'parte eu espero vos no próximo '
#                                          'vídeo'},
#                        {   'transcript': 'e para quem não é inscrito subscreva '
#                                          'porque faz toda a diferença aqui no '
#                                          'projeto Muito obrigado a todos pelo '
#                                          'vosso contributo já sabem da minha '
#                                          'parte eu espero-vos no próximo '
#                                          'vídeo'},
#                        {   'transcript': 'e para quem não é inscrito subscreva '
#                                          'porque faz toda a diferença aqui no '
#                                          'projeto muito obrigada a todos pelo '
#                                          'vosso contributo já sabem da minha '
#                                          'parte eu espero-nos no próximo '
#                                          'vídeo'}],
#     'final': True}
# audio-chunks/chunk54.wav : E para quem não é inscrito subscreva porque faz toda a diferença aqui no projeto muito obrigada a todos pelo vosso contributo já sabem da minha parte eu espero-vos no próximo vídeo.
#
# Texto PT: Hoje vamos falar como devemos planear financeiramente o novo ano olá a todos o meu nome é ariana nunes e este é o canal renda maior este vídeo para por favor deixarem ficar o seu gosto. Em cima tudo para quem ainda não é inscrito por favor clique no botão que está aqui embaixo e faça parte deste projeto. Porque se fosse porque no gesto significa muito para mim e ficarei extremamente agradecida por ajudarem o canal renda maior a chegar mais longe hoje vamos falar da importância de ter um plano financeiro para este novo ano tendo em conta que começou o mesmo e nós temos que ter metas definidas. Todos os anos a primeira coisa que eu faço no início do ano é definir qual é a média que eu quero ter em termos financeiros no final do ano isto é a 31 de dezembro isso significa neste caso ter também atenção obviamente ao meu orçamento à minha poupança e claro aos meus rendimentos podemos todos comer as 12 passas e pedir uma série de desejos inclusive poder neste caso enriquecer durante este próximo ano mas se não fizemos nada provavelmente também não irá acontecer nada. E desta forma eu vou falar aqui sobre algumas coisas que eu faço que pode ajudar muita gente desse. Organizar finance. Para regra financeira que maior parte dos indicadores financeiros falam nos livros e que comenta por todos esses vídeos que vocês já viram no youtube tem a ver então com o poupança e nomeadamente com o valor que vocês devem poupar por mês. Lógico que se vemos mensalmente aquilo que nós devemos fazer é sempre tirar uma porcentagem desse rendimento para nós próprio. Desta forma o que os manuais dizem é que será no mínimo 10%. Da minha ótica 10% não serve para muito é pouco mais do que um salário extra no final do ano e já que temos também o décimo terceiro mês e o suficiente de férias porque não também contar com esses subsídios para podermos aqui ampliar essa taxa de poupança na minha ótica acho que devemos sempre tentar fazer um esforço maior e pelo menos poupar 15% do nosso rendimento mensal e 15% também de cada subsídio que nós tínhamos em terceiro lugar acho que é muito importante perceber em que é necessário termos uma renda extra seja ela ativa ou passiva seja algo que vocês conseguem ter por exemplo criaram um e-book. Alguma das vossas skills das vossas competências e conseguiram vender o mesmo sejam por exemplo ativamente ajudarem no restaurante a servir ou fazer qualquer outra coisa que vos permite a ganhar dinheiro e desta forma ter uma renda extra vai-vos aumentar a vossa capacidade de poupança isso pode fazer toda a diferença no final do mês. Energia está então neste caso no mult rendimento não ter só o salário mas sem ter outros negócios outras atividades. Vos posso ajudar dinheiro mensalmente e com isso consigam então aumentar a vossa poupança anual. Desta forma para poderem realizar os vossos objetivos mas também ter um conforto financeiro porque no final do ano se vocês tiverem mais 1000 3000 5000 10.000 de acordo com os vossos rendimentos e com a vossa capacidade de poupança isso vai se fazer vocês pessoas mais seguras e mais tranquilas em relação à vida porque infelizmente as coisas acontecem e nós temos que estar preparados lembre-se que não teremos os mesmos rendimentos os mesmos objetivos e despesas a mesma capacidade de poupança e por isso é importante perceber que não se devem comparar as outras pessoas porque muitas vezes é impossível comparar. Do coqueiro das formas vocês devem sempre pensar que se alguém consegue alcançar algum objetivo como fazer uma viagem ou constantemente estar a ir a restaurantes não tá fora não significa que aquela pessoa esteja a fazer uma matização financeira simplesmente poderá ter mais renda extra poderá receber mais poderá fazer outra coisa diferente de vocês. Muitas vezes capacitamos através do estudo através da realização profissional através efetivamente de mais trabalho conseguimos muitas vezes adquir. O valor superior em termos de rendimento. Com certeza que devem sempre apostar no vosso ...
