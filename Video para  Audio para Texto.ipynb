# %%
#Run this only if these 2 modules aren't yet installed
# !pip3 install SpeechRecognition pydub

# %% [markdown]
# ## 1. Extrair o Audio para um ficheiro "audio.wav"

# %%
import subprocess
command = 'ffmpeg -i /home/jovyan/2023-01-11.mp4 -ab 160k -ar 44100 -vn /home/jovyan/audio.wav'
subprocess.call(command, shell=True)

# %% [markdown]
# ## 2. Inicializar o Recognizer

# %%
import speech_recognition as sr
# initialize the recognizer
r = sr.Recognizer()

# %% [markdown]
# ## 3. Função que dividir o ficheiro audio em pedaços de alguns segundos
# #### (detecção de frases) e faz o respectivo reconhecimento de cada pedaço
# Deste modo não é necessário fazer o upload para a Cloud do Google -- a separação entre pedaços é feita com base nos momentos de pausa entre palavras para não as cortar a meio.

# %%
# importing libraries 
import speech_recognition as sr 
import os 
from pydub import AudioSegment
from pydub.silence import split_on_silence

# create a speech recognition object
r = sr.Recognizer()

# a function that splits the audio file into chunks
# and applies speech recognition
def get_large_audio_transcription(path):
    """
    Splitting the large audio file into chunks
    and apply speech recognition on each of these chunks
    """
    # open the audio file using pydub
    sound = AudioSegment.from_wav(path)  
    # split audio sound where silence is 700 miliseconds or more and get chunks
    chunks = split_on_silence(sound,
        # experiment with this value for your target audio file
        min_silence_len = 500,
        # adjust this per requirement
        silence_thresh = sound.dBFS-14,
        # keep the silence for 1 second, adjustable as well
        keep_silence=500,
    )
    folder_name = "audio-chunks"
    # create a directory to store the audio chunks
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    whole_text = ""
    # process each chunk 
    for i, audio_chunk in enumerate(chunks, start=1):
        # export audio chunk and save it in
        # the `folder_name` directory.
        chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
        audio_chunk.export(chunk_filename, format="wav")
        # recognize the chunk
        with sr.AudioFile(chunk_filename) as source:
            audio_listened = r.record(source)
            # try converting it to text
            try:
                text = r.recognize_google(audio_listened)
            except sr.UnknownValueError as e:
                print("Error:", str(e))
            else:
                text = f"{text.capitalize()}. "
                print(chunk_filename, ":", text)
                whole_text += text
    # return the text for all chunks detected
    return whole_text

# %% [markdown]
# ## 3. Executar a função com o audio extraído do video
# A saída é apresentada a seguir a "Todo o Texto"

# %%
path = "audio.wav"
print("\nTodo o Texto:", get_large_audio_transcription(path))
# Out:
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.85446787,
#                            'transcript': 'so we at the file share by the'},
#                        {'transcript': 'so we have to file share by the'},
#                        {'transcript': 'so we have the file share by the'},
#                        {'transcript': 'so we have the file shared by the'},
#                        {'transcript': 'so we had to file share by the'}],
#     'final': True}
# audio-chunks/chunk2.wav : So we at the file share by the.
# result2:
# {   'alternative': [   {   'confidence': 0.89431751,
#                            'transcript': "repository team for instance let's "
#                                          "AIDS day today as today it's not "
#                                          "it's one for the best Bedford is "
#                                          'purpose'},
#                        {   'transcript': "repository team for instance let's "
#                                          "say it's dated jazz today it's not "
#                                          "it's one for the best Bedford is "
#                                          'purpose'},
#                        {   'transcript': "repository team for instance let's "
#                                          "AIDS day today as today it's not "
#                                          "it's 14 the best Bedford is purpose"},
#                        {   'transcript': "repository team for instance let's "
#                                          "say it's dated as today it's not "
#                                          "it's one for the best Bedford is "
#                                          'purpose'},
#                        {   'transcript': "repository team for instance let's a "
#                                          "date as today it's not it's one for "
#                                          'the best Bedford is purpose'}],
#     'final': True}
# audio-chunks/chunk3.wav : Repository team for instance let's aids day today as today it's not it's one for the best bedford is purpose.
# result2:
# {   'alternative': [   {   'confidence': 0.92715794,
#                            'transcript': 'just an example what we need to do '
#                                          'first is to upload it'},
#                        {   'transcript': 'just an example what we need to do '
#                                          'first is to uploader'},
#                        {   'transcript': 'just an example what we need to do '
#                                          'first is to upload to'},
#                        {   'transcript': 'just done a sample what we need to '
#                                          'do first is to upload it'},
#                        {   'transcript': 'just an example what we need to do '
#                                          'first is to a bloated'}],
#     'final': True}
# audio-chunks/chunk4.wav : Just an example what we need to do first is to upload it.
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.95467675,
#                            'transcript': 'the directory where we handle all '
#                                          'the data transformation'},
#                        {   'transcript': 'the directory where we handle all '
#                                          'the date of transformation'},
#                        {   'transcript': 'the directory while we handle all '
#                                          'the data transformation'},
#                        {   'transcript': 'the directory where we handle all '
#                                          'the day transformation'},
#                        {   'transcript': 'the directory while we handle all '
#                                          'the date of transformation'}],
#     'final': True}
# audio-chunks/chunk6.wav : The directory where we handle all the data transformation.
# result2:
# {   'alternative': [   {   'confidence': 0.94874644,
#                            'transcript': 'and Four Tet we are going to simply '
#                                          'drag and drop from where it is '
#                                          "that's it mentioned it's in the "
#                                          'downloads folder upload it here'},
#                        {   'transcript': 'and for that we are going to simply '
#                                          'drag and drop from where it is '
#                                          "that's it mentioned it's in the "
#                                          'downloads folder upload it here'},
#                        {   'transcript': 'and Four Tet we are going to simply '
#                                          'drag and drop from where it is '
#                                          "that's it mentioned that it's in the "
#                                          'downloads folder upload it here'},
#                        {   'transcript': 'and Four Tet we are going to simply '
#                                          'drag and drop from where it is '
#                                          "that's it mission that it's in the "
#                                          'downloads folder upload it here'},
#                        {   'transcript': 'and for that we are going to simply '
#                                          'drag and drop from where it is '
#                                          "that's it mentioned that it's in the "
#                                          'downloads folder upload it here'}],
#     'final': True}
# audio-chunks/chunk7.wav : And four tet we are going to simply drag and drop from where it is that's it mentioned it's in the downloads folder upload it here.
# result2:
# {   'alternative': [   {   'confidence': 0.94411194,
#                            'transcript': 'and change the name'},
#                        {'transcript': 'and changed the name'},
#                        {'transcript': 'and change their name'},
#                        {'transcript': 'and I change the name'}],
#     'final': True}
# audio-chunks/chunk8.wav : And change the name.
# result2:
# {   'alternative': [   {   'confidence': 0.93667358,
#                            'transcript': 'what it is expecting that is without '
#                                          'the date'},
#                        {   'transcript': 'to what it is expecting that is '
#                                          'without the date'},
#                        {   'transcript': "what it is expecting that he's "
#                                          'without the date'},
#                        {   'transcript': 'what it is expecting dirtiest '
#                                          'without the date'},
#                        {   'transcript': 'what it is expecting that it is '
#                                          'without the date'}],
#     'final': True}
# audio-chunks/chunk9.wav : What it is expecting that is without the date.
# result2:
# {   'alternative': [   {   'confidence': 0.92405623,
#                            'transcript': 'we have uploaded'},
#                        {'transcript': 'we have applauded'},
#                        {'transcript': 'we have uploader'},
#                        {'transcript': 'we have a bloody'},
#                        {'transcript': 'we have applied it'}],
#     'final': True}
# audio-chunks/chunk10.wav : We have uploaded.
# result2:
# {   'alternative': [   {   'confidence': 0.95155424,
#                            'transcript': 'it will ask us to overwrite if you '
#                                          'want to overwrite we want to '
#                                          "overwrite because it's a new version "
#                                          'and now we are ready to run'},
#                        {   'transcript': 'it will ask us to write if you want '
#                                          'to overwrite we want to overwrite '
#                                          "because it's a new version and now "
#                                          'we are ready to run'},
#                        {   'transcript': 'it will ask us to alright if you '
#                                          'want to overwrite we want to '
#                                          "overwrite because it's a new version "
#                                          'and now we are ready to run'},
#                        {   'transcript': 'it will ask as to overwrite if you '
#                                          'want to overwrite we want to '
#                                          "overwrite because it's a new version "
#                                          'and now we are ready to run'},
#                        {   'transcript': 'it will ask us to overwrite if you '
#                                          'want to overwrite we want to '
#                                          "overwrite because it's a newer "
#                                          'version and now we are ready to '
#                                          'run'}],
#     'final': True}
# audio-chunks/chunk11.wav : It will ask us to overwrite if you want to overwrite we want to overwrite because it's a new version and now we are ready to run.
# result2:
# {   'alternative': [   {'confidence': 0.86485827, 'transcript': 'the'},
#                        {'transcript': 'there'},
#                        {'transcript': 'the air'}],
#     'final': True}
# audio-chunks/chunk12.wav : The.
# result2:
# {   'alternative': [   {   'confidence': 0.87726569,
#                            'transcript': 'network that will handle'},
#                        {'transcript': 'the network that will handle'},
#                        {'transcript': 'The Notebook death will handle'},
#                        {'transcript': 'network depth wheel handle'},
#                        {'transcript': 'show me the network that will handle'}],
#     'final': True}
# audio-chunks/chunk13.wav : Network that will handle.
# result2:
# {   'alternative': [   {   'confidence': 0.93101156,
#                            'transcript': "these transformations so it's this "
#                                          'one IRA person'},
#                        {   'transcript': "these transformations so it's this "
#                                          'one Irish person'},
#                        {   'transcript': "these transformations so it's this "
#                                          'one IRA passing'},
#                        {   'transcript': "these transformations so it's this "
#                                          'one IRA parsing'},
#                        {   'transcript': "these transformation so it's this "
#                                          'one IRA person'}],
#     'final': True}
# audio-chunks/chunk14.wav : These transformations so it's this one ira person.
# result2:
# {   'alternative': [   {   'confidence': 0.92836362,
#                            'transcript': 'and European you can run cell by '
#                                          'cell'},
#                        {'transcript': 'and European you can run sell buy sell'},
#                        {'transcript': 'and European you can run cell buy sell'},
#                        {'transcript': 'and European you can run sell-by sell'},
#                        {   'transcript': 'and European you can run cells by '
#                                          'cell'}],
#     'final': True}
# audio-chunks/chunk15.wav : And european you can run cell by cell.
# result2:
# {   'alternative': [   {'confidence': 0.93445098, 'transcript': 'or simply'},
#                        {'transcript': 'are simply'},
#                        {'transcript': 'or simple'},
#                        {'transcript': 'or Sinclair'},
#                        {'transcript': 'or sink'}],
#     'final': True}
# audio-chunks/chunk16.wav : Or simply.
# result2:
# {   'alternative': [   {   'confidence': 0.90990567,
#                            'transcript': 'run all the cells'},
#                        {'transcript': 'ran all the cells'},
#                        {'transcript': 'run older cells'},
#                        {'transcript': 'ran all the sells'},
#                        {'transcript': 'ran all the sales'}],
#     'final': True}
# audio-chunks/chunk17.wav : Run all the cells.
# result2:
# {   'alternative': [   {   'confidence': 0.90751565,
#                            'transcript': 'at 1 so run on'},
#                        {'transcript': 'Edwin so run on'},
#                        {'transcript': 'at 1 so run-on'},
#                        {'transcript': 'at one so run on'},
#                        {'transcript': 'at once so run on'}],
#     'final': True}
# audio-chunks/chunk18.wav : At 1 so run on.
# result2:
# {   'alternative': [{'confidence': 0.85773998, 'transcript': 'and'}],
#     'final': True}
# audio-chunks/chunk19.wav : And.
# result2:
# {   'alternative': [   {'confidence': 0.81076443, 'transcript': 'running'},
#                        {'transcript': "it's running"},
#                        {'transcript': 'training'},
#                        {'transcript': 'traning'}],
#     'final': True}
# audio-chunks/chunk20.wav : Running.
# result2:
# {   'alternative': [   {   'confidence': 0.75331855,
#                            'transcript': 'are the films here'},
#                        {'transcript': 'are the fuel serum'},
#                        {'transcript': 'are the fuels here'},
#                        {'transcript': 'are the feels here'},
#                        {'transcript': 'are the fields here'}],
#     'final': True}
# audio-chunks/chunk21.wav : Are the films here.
# result2:
# {   'alternative': [   {   'confidence': 0.89149606,
#                            'transcript': 'turn my pressure on stick a little '
#                                          'bit more time'},
#                        {   'transcript': 'turn my depression stick a little '
#                                          'bit more time'},
#                        {   'transcript': 'turn my patience take a little bit '
#                                          'more time'},
#                        {   'transcript': 'turn my probation stick a little bit '
#                                          'more time'},
#                        {   'transcript': 'turn my progression stick a little '
#                                          'bit more time'}],
#     'final': True}
# audio-chunks/chunk22.wav : Turn my pressure on stick a little bit more time.
# result2:
# {   'alternative': [   {   'confidence': 0.93303865,
#                            'transcript': 'this one still has 80 records'},
#                        {'transcript': 'this one still has 80 red cards'},
#                        {'transcript': "this one's still has 80 records"},
#                        {'transcript': 'this one still has a tree records'},
#                        {'transcript': 'this once still has 80 records'}],
#     'final': True}
# audio-chunks/chunk23.wav : This one still has 80 records.
# result2:
# {   'alternative': [   {   'confidence': 0.94519734,
#                            'transcript': 'UCAS produced'},
#                        {'transcript': 'UCAS produce'},
#                        {'transcript': 'ukas produced'},
#                        {'transcript': 'you cast produced'},
#                        {'transcript': 'ukas produce'}],
#     'final': True}
# audio-chunks/chunk24.wav : Ucas produced.
# result2:
# {   'alternative': [   {'confidence': 0.77103919, 'transcript': 'Hertford'},
#                        {'transcript': 'Hartford'},
#                        {'transcript': 'Watford'},
#                        {'transcript': 'Oxford'},
#                        {'transcript': 'Bedford'}],
#     'final': True}
# audio-chunks/chunk25.wav : Hertford.
# result2:
# {   'alternative': [   {   'confidence': 0.85709637,
#                            'transcript': 'generate Excel file'},
#                        {'transcript': 'generate the Excel file'},
#                        {'transcript': 'generated the Excel file'},
#                        {'transcript': 'generate at the Excel file'},
#                        {'transcript': 'generated at the Excel file'}],
#     'final': True}
# audio-chunks/chunk26.wav : Generate excel file.
# result2:
# {   'alternative': [   {'confidence': 0.89376503, 'transcript': 'that we want'},
#                        {'transcript': 'bet we want'},
#                        {'transcript': 'let we want'},
#                        {'transcript': 'debt we want'},
#                        {'transcript': "that we won't"}],
#     'final': True}
# audio-chunks/chunk27.wav : That we want.
# result2:
# {   'alternative': [   {   'confidence': 0.87835395,
#                            'transcript': 'so we have now these Excel file'},
#                        {'transcript': 'so we have now this Excel file'},
#                        {'transcript': 'so we have nowadays Excel file'},
#                        {'transcript': 'so we have no these Excel file'},
#                        {'transcript': 'so we have now this XML file'}],
#     'final': True}
# audio-chunks/chunk28.wav : So we have now these excel file.
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.89189899,
#                            'transcript': "I won't be allowed Frazier Street "
#                                          'what you need to do is create a '
#                                          'table on'},
#                        {   'transcript': "I won't be allowed Frasier Street "
#                                          'what you need to do is create a '
#                                          'table on'},
#                        {   'transcript': "I won't be allowed Frasier stream "
#                                          'what you need to do is create a '
#                                          'table on'},
#                        {   'transcript': "I won't be allowed Fraser Street "
#                                          'what you need to do is create a '
#                                          'table on'},
#                        {   'transcript': "I won't be allowed Frazier Street "
#                                          'what you need to do is create a '
#                                          'table on it'}],
#     'final': True}
# audio-chunks/chunk30.wav : I won't be allowed frazier street what you need to do is create a table on.
# result2:
# {   'alternative': [   {   'confidence': 0.80313945,
#                            'transcript': 'so for that purpose'},
#                        {'transcript': 'sulfate purpose'},
#                        {'transcript': 'sofatech purpose'},
#                        {'transcript': 'sofa Ted purpose'},
#                        {'transcript': 'Sofitel purpose'}],
#     'final': True}
# audio-chunks/chunk31.wav : So for that purpose.
# result2:
# {   'alternative': [   {   'confidence': 0.85100025,
#                            'transcript': "let's download the"},
#                        {'transcript': "let's download.the"},
#                        {'transcript': 'Letts download the'},
#                        {'transcript': 'lets download the'}],
#     'final': True}
# audio-chunks/chunk32.wav : Let's download the.
# result2:
# {   'alternative': [   {'confidence': 0.82288355, 'transcript': 'file'},
#                        {'transcript': 'final'},
#                        {'transcript': 'vile'},
#                        {'transcript': 'phial'},
#                        {'transcript': 'biol'}],
#     'final': True}
# audio-chunks/chunk33.wav : File.
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {'confidence': 0.92430341, 'transcript': 'sorry'},
#                        {'transcript': 'Surrey'}],
#     'final': True}
# audio-chunks/chunk35.wav : Sorry.
# result2:
# {   'alternative': [   {   'confidence': 0.92823207,
#                            'transcript': "let's download the file by selecting "
#                                          'it'},
#                        {   'transcript': "let's download the file by selecting "
#                                          'Gate'},
#                        {   'transcript': 'lights download the file by '
#                                          'selecting it'},
#                        {   'transcript': "let's download The Fire by selecting "
#                                          'it'},
#                        {   'transcript': 'lets download the file by selecting '
#                                          'it'}],
#     'final': True}
# audio-chunks/chunk36.wav : Let's download the file by selecting it.
# result2:
# {   'alternative': [   {'confidence': 0.88736832, 'transcript': 'and opening'},
#                        {'transcript': 'and open it'},
#                        {'transcript': 'and opener'},
#                        {'transcript': 'and open'},
#                        {'transcript': 'and opened it'}],
#     'final': True}
# audio-chunks/chunk37.wav : And opening.
# result2:
# {   'alternative': [   {'confidence': 0.22352789, 'transcript': 'cheer'},
#                        {'transcript': 'Shere'},
#                        {'transcript': 'sheer'},
#                        {'transcript': 'shear'},
#                        {'transcript': 'Sher'}],
#     'final': True}
# audio-chunks/chunk38.wav : Cheer.
# result2:
# {   'alternative': [   {   'confidence': 0.94450003,
#                            'transcript': 'we need to make sure that we select '
#                                          'all the fields and all the records'},
#                        {   'transcript': 'we need to make sure that we select '
#                                          'all the fuels and all the records'},
#                        {   'transcript': 'we need to make sure that will '
#                                          'select all the fields and all the '
#                                          'records'},
#                        {   'transcript': 'you need to make sure that we select '
#                                          'all the fields and all the records'},
#                        {   'transcript': 'we need to make sure that we select '
#                                          'all the fields and all the red '
#                                          'cards'}],
#     'final': True}
# audio-chunks/chunk39.wav : We need to make sure that we select all the fields and all the records.
# result2:
# {   'alternative': [   {   'confidence': 0.92861456,
#                            'transcript': 'and if you see the instructions '
#                                          'here'},
#                        {'transcript': 'and if you see the instructions year'},
#                        {'transcript': 'and if you see the instructions you'},
#                        {'transcript': 'and if you see their instructions here'},
#                        {'transcript': 'and if you see that instructions here'}],
#     'final': True}
# audio-chunks/chunk40.wav : And if you see the instructions here.
# result2:
# {   'alternative': [   {   'confidence': 0.94202799,
#                            'transcript': 'select all the fields and all the '
#                                          'records'},
#                        {   'transcript': 'select all the fields and other '
#                                          'records'},
#                        {   'transcript': 'select all the fields and down the '
#                                          'road chords'},
#                        {   'transcript': 'select all the fields and out the '
#                                          'records'},
#                        {   'transcript': 'select all the fields and down the '
#                                          'records'}],
#     'final': True}
# audio-chunks/chunk41.wav : Select all the fields and all the records.
# result2:
# {   'alternative': [   {'confidence': 0.91882938, 'transcript': 'and go'},
#                        {'transcript': 'and Co'},
#                        {'transcript': 'and gold'},
#                        {'transcript': 'ankle'},
#                        {'transcript': 'angle'}],
#     'final': True}
# audio-chunks/chunk42.wav : And go.
# result2:
# {   'alternative': [   {   'confidence': 0.88798702,
#                            'transcript': 'took the home menu and format as '
#                                          'table'},
#                        {'transcript': 'took the home menu and formats table'},
#                        {'transcript': 'talk to home menu and format as table'},
#                        {   'transcript': 'took the home menu and formatted '
#                                          'stable'},
#                        {   'transcript': 'talk to the home menu and format as '
#                                          'table'}],
#     'final': True}
# audio-chunks/chunk43.wav : Took the home menu and format as table.
# result2:
# {   'alternative': [   {'confidence': 0.88004524, 'transcript': 'so home menu'},
#                        {'transcript': 'Soho home menu'},
#                        {'transcript': 'sow home menu'},
#                        {'transcript': 'sew home menu'},
#                        {'transcript': 'sohom menu'}],
#     'final': True}
# audio-chunks/chunk44.wav : So home menu.
# result2:
# {   'alternative': [{'confidence': 0.91435921, 'transcript': 'and then'}],
#     'final': True}
# audio-chunks/chunk45.wav : And then.
# result2:
# {   'alternative': [   {   'confidence': 0.95467669,
#                            'transcript': 'format as table'},
#                        {'transcript': 'format as a table'}],
#     'final': True}
# audio-chunks/chunk46.wav : Format as table.
# result2:
# {   'alternative': [   {   'confidence': 0.80711508,
#                            'transcript': "doesn't matter"},
#                        {'transcript': "doesn't matter now"}],
#     'final': True}
# audio-chunks/chunk47.wav : Doesn't matter.
# result2:
# {   'alternative': [   {   'confidence': 0.70997757,
#                            'transcript': 'David Brooks shoes'},
#                        {'transcript': 'the vehicle looks shoes'},
#                        {'transcript': 'David Brooks'},
#                        {'transcript': 'David Hollyoaks'},
#                        {'transcript': 'the vehicle looks'}],
#     'final': True}
# audio-chunks/chunk48.wav : David brooks shoes.
# result2:
# {   'alternative': [{'confidence': 0.9493885, 'transcript': 'any of it'}],
#     'final': True}
# audio-chunks/chunk49.wav : Any of it.
# result2:
# {   'alternative': [   {'confidence': 0.7655412, 'transcript': 'any'},
#                        {'transcript': 'ne'},
#                        {'transcript': 'NY'},
#                        {'transcript': 'n e'},
#                        {'transcript': 'enny'}],
#     'final': True}
# audio-chunks/chunk50.wav : Any.
# result2:
# {   'alternative': [   {'confidence': 0.85035944, 'transcript': 'choose any'},
#                        {'transcript': 'true surname'},
#                        {'transcript': 'shoes any'},
#                        {'transcript': 'true cny'},
#                        {'transcript': 'true CNA'}],
#     'final': True}
# audio-chunks/chunk51.wav : Choose any.
# result2:
# {   'alternative': [   {   'confidence': 0.93852049,
#                            'transcript': "accepted value that's the ones we "
#                                          'have selected'},
#                        {   'transcript': "accepted value that's the ones we "
#                                          'have selected it'},
#                        {   'transcript': "accepted value it's the ones we have "
#                                          'selected'},
#                        {   'transcript': "acceptable you that's the ones we "
#                                          'have selected'},
#                        {   'transcript': "acceptable new that's the ones we "
#                                          'have selected'}],
#     'final': True}
# audio-chunks/chunk52.wav : Accepted value that's the ones we have selected.
# result2:
# {   'alternative': [   {   'confidence': 0.92402959,
#                            'transcript': 'it will create the table name'},
#                        {'transcript': 'it will create a table name'},
#                        {'transcript': 'it will create table name'},
#                        {'transcript': 'it will creator table name'},
#                        {'transcript': 'it will create table names'}],
#     'final': True}
# audio-chunks/chunk53.wav : It will create the table name.
# result2:
# {   'alternative': [   {'confidence': 0.66737062, 'transcript': 'call'},
#                        {'transcript': 'car'},
#                        {'transcript': 'Cork'},
#                        {'transcript': 'caught'}],
#     'final': True}
# audio-chunks/chunk54.wav : Call.
# result2:
# {   'alternative': [   {'confidence': 0.95467669, 'transcript': 'table 1'},
#                        {'transcript': 'table1'}],
#     'final': True}
# audio-chunks/chunk55.wav : Table 1.
# result2:
# {   'alternative': [   {   'confidence': 0.93412799,
#                            'transcript': "Perfect that's what we want"},
#                        {'transcript': "that's what we want"},
#                        {'transcript': "perfect it's what we want"},
#                        {'transcript': 'perfect hips what we want'},
#                        {'transcript': 'perfect x what we want'}],
#     'final': True}
# audio-chunks/chunk56.wav : Perfect that's what we want.
# result2:
# {   'alternative': [   {   'confidence': 0.85568619,
#                            'transcript': 'and what part m expecting'},
#                        {'transcript': 'and what parrot mate is expecting'},
#                        {'transcript': 'and what other tonight is expecting'},
#                        {'transcript': 'and what other two mate is expecting'},
#                        {'transcript': 'and what order to make is expecting'}],
#     'final': True}
# audio-chunks/chunk57.wav : And what part m expecting.
# result2:
# {   'alternative': [   {   'confidence': 0.91044015,
#                            'transcript': 'as distractions here'},
#                        {'transcript': 'as distraction is here'},
#                        {'transcript': 'as distractions hear'},
#                        {'transcript': 'as destructions here'},
#                        {'transcript': 'as this fractions here'}],
#     'final': True}
# audio-chunks/chunk58.wav : As distractions here.
# result2:
# {   'alternative': [   {   'confidence': 0.93869674,
#                            'transcript': 'so what are you going to do now is '
#                                          'to'},
#                        {'transcript': 'so what you going to do now is to'},
#                        {'transcript': 'so what we going to do now is to'},
#                        {'transcript': 'so what do you going to do now is to'},
#                        {   'transcript': 'so what are you going to do now is '
#                                          'too'}],
#     'final': True}
# audio-chunks/chunk59.wav : So what are you going to do now is to.
# result2:
# {   'alternative': [   {'confidence': 0.73280311, 'transcript': 'applauded'},
#                        {'transcript': 'uploaded'},
#                        {'transcript': 'applaud it'},
#                        {'transcript': 'upload it'}],
#     'final': True}
# audio-chunks/chunk60.wav : Applauded.
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {'confidence': 0.90114391, 'transcript': 'the file'},
#                        {'transcript': 'defile'}],
#     'final': True}
# audio-chunks/chunk62.wav : The file.
# result2:
# {   'alternative': [   {   'confidence': 0.82450926,
#                            'transcript': 'where it expect to be'},
#                        {'transcript': 'where it expects to be'},
#                        {'transcript': 'what it expects to be'},
#                        {'transcript': 'where is it expected to be'},
#                        {'transcript': 'well it expect to be'}],
#     'final': True}
# audio-chunks/chunk63.wav : Where it expect to be.
# result2:
# {   'alternative': [   {   'confidence': 0.9186824,
#                            'transcript': "define here so I'm going to replace "
#                                          'this'},
#                        {   'transcript': "the final year so I'm going to "
#                                          'replace this'},
#                        {   'transcript': "the file here so I'm going to "
#                                          'replace this'},
#                        {   'transcript': "define year so I'm going to replace "
#                                          'this'},
#                        {   'transcript': "define here so I'm going to replace "
#                                          'these'}],
#     'final': True}
# audio-chunks/chunk64.wav : Define here so i'm going to replace this.
# result2:
# {   'alternative': [   {'confidence': 0.95023757, 'transcript': 'old one here'},
#                        {'transcript': 'old one hear'},
#                        {'transcript': 'Old Wine here'},
#                        {'transcript': 'old 1 here'}],
#     'final': True}
# audio-chunks/chunk65.wav : Old one here.
# result2:
# {   'alternative': [   {   'confidence': 0.91824758,
#                            'transcript': 'let me close it'},
#                        {'transcript': 'so let me close it'},
#                        {'transcript': 'wake me closet'},
#                        {'transcript': 'let me close at'},
#                        {'transcript': 'wake me close it'}],
#     'final': True}
# audio-chunks/chunk66.wav : Let me close it.
# result2:
# {   'alternative': [{'confidence': 0.92318839, 'transcript': 'again'}],
#     'final': True}
# audio-chunks/chunk67.wav : Again.
# result2:
# {   'alternative': [   {   'confidence': 0.88770843,
#                            'transcript': 'drag and drop so this is the '
#                                          'fireworks changed'},
#                        {   'transcript': 'dragon drop so this is the fireworks '
#                                          'changed'},
#                        {   'transcript': 'drag-and-drop so this is the '
#                                          'fireworks changed'},
#                        {   'transcript': 'drag and drop so this is the file '
#                                          'where changed'},
#                        {   'transcript': 'dragon drop so this is the file '
#                                          'where changed'}],
#     'final': True}
# audio-chunks/chunk68.wav : Drag and drop so this is the fireworks changed.
# result2:
# {   'alternative': [   {   'confidence': 0.95467669,
#                            'transcript': 'drag and drop to replace it'},
#                        {'transcript': 'dragon drop to replace it'},
#                        {'transcript': 'dragon dropped to replace it'},
#                        {'transcript': 'dragon drive to replace it'}],
#     'final': True}
# audio-chunks/chunk69.wav : Drag and drop to replace it.
# result2:
# {   'alternative': [   {   'confidence': 0.93238336,
#                            'transcript': 'replace yes replace the the one that '
#                                          'it was there'},
#                        {   'transcript': 'replace yes replace there the one '
#                                          'that it was there'},
#                        {   'transcript': 'replace yes replace the the one that '
#                                          'was there'},
#                        {   'transcript': 'replace yes replace there the one '
#                                          'that was there'},
#                        {   'transcript': 'replace yes replace their the one '
#                                          'that it was there'}],
#     'final': True}
# audio-chunks/chunk70.wav : Replace yes replace the the one that it was there.
# result2:
# {   'alternative': [   {   'confidence': 0.91175193,
#                            'transcript': 'and now we are ready to rent Karachi '
#                                          'mate I know the address but let me '
#                                          'just click here'},
#                        {   'transcript': 'and now we are ready to rent Karachi '
#                                          'mate I know the address but like '
#                                          'mistress liqueur'},
#                        {   'transcript': 'and now we are ready to rent karate '
#                                          'mate I know the address but let me '
#                                          'just click here'},
#                        {   'transcript': 'and now we are ready to rent Karachi '
#                                          'mate I know the address but like Mrs '
#                                          'liqueur'},
#                        {   'transcript': 'and now we are ready to rent Karachi '
#                                          'mate I know the actress but like Mrs '
#                                          'liqueur'}],
#     'final': True}
# audio-chunks/chunk71.wav : And now we are ready to rent karachi mate i know the address but let me just click here.
# result2:
# {   'alternative': [   {   'confidence': 0.84367484,
#                            'transcript': 'and you are not seeing me'},
#                        {'transcript': "and you're not seeing me"},
#                        {'transcript': 'you are not seeing me'},
#                        {'transcript': "and you're not seen me"},
#                        {'transcript': 'and I was not seeing me'}],
#     'final': True}
# audio-chunks/chunk72.wav : And you are not seeing me.
# result2:
# []
# Error:
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.83846718,
#                            'transcript': 'and we are in power automate'},
#                        {'transcript': 'angry are in power automate'},
#                        {'transcript': 'angry r in power automate'},
#                        {'transcript': 'Anglia in power automate'},
#                        {'transcript': 'Anglia are in power automate'}],
#     'final': True}
# audio-chunks/chunk75.wav : And we are in power automate.
# result2:
# {   'alternative': [   {   'confidence': 0.9020592,
#                            'transcript': 'the flow depth we need'},
#                        {'transcript': 'the flow that we need'},
#                        {'transcript': 'the flow depth you need'}],
#     'final': True}
# audio-chunks/chunk76.wav : The flow depth we need.
# result2:
# {   'alternative': [   {'confidence': 0.61653084, 'transcript': 'Quran'},
#                        {'transcript': 'Touran'},
#                        {'transcript': 'Darren'},
#                        {'transcript': 'Taryn'},
#                        {'transcript': 'Sharan'}],
#     'final': True}
# audio-chunks/chunk77.wav : Quran.
# result2:
# {   'alternative': [   {   'confidence': 0.897021,
#                            'transcript': 'your track here is update'},
#                        {'transcript': 'your track here is up day'},
#                        {'transcript': 'your trick here is update'},
#                        {'transcript': 'your check here is update'},
#                        {'transcript': 'Utrecht here is update'}],
#     'final': True}
# audio-chunks/chunk78.wav : Your track here is update.
# result2:
# {   'alternative': [   {   'confidence': 0.54886287,
#                            'transcript': 'rebel datasets'},
#                        {'transcript': 'read data sets'},
#                        {'transcript': 'Red Bull data sets'},
#                        {'transcript': 'rebel data sets'},
#                        {'transcript': 'Red Bull datasets'}],
#     'final': True}
# audio-chunks/chunk79.wav : Rebel datasets.
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.88256907,
#                            'transcript': 'sew update report datasets'},
#                        {'transcript': 'so update report datasets'},
#                        {'transcript': 'sow update report datasets'},
#                        {'transcript': 'so update report data sets'},
#                        {'transcript': 'sew update report data sets'}],
#     'final': True}
# audio-chunks/chunk81.wav : Sew update report datasets.
# result2:
# {   'alternative': [   {   'confidence': 0.94630134,
#                            'transcript': "I'm not going to run it now because "
#                                          "I don't want to that's not know "
#                                          "nothing you want it I'm just going "
#                                          'to show you'},
#                        {   'transcript': "I'm not going to run it now because "
#                                          "I don't want to that's not no "
#                                          "nothing you want it I'm just going "
#                                          'to show you'},
#                        {   'transcript': "I'm not going to run it now because "
#                                          "I don't want to that's not know "
#                                          "nothing new one it I'm just going to "
#                                          'show you'},
#                        {   'transcript': "I'm not going to run it now because "
#                                          "I don't want to that's not know "
#                                          "nothing you won't it I'm just going "
#                                          'to show you'},
#                        {   'transcript': "I'm not going to run it now because "
#                                          "I don't want to does not know "
#                                          "nothing you want it I'm just going "
#                                          'to show you'}],
#     'final': True}
# audio-chunks/chunk82.wav : I'm not going to run it now because i don't want to that's not know nothing you want it i'm just going to show you.
# result2:
# {   'alternative': [   {   'confidence': 0.794774,
#                            'transcript': 'what it has inside'},
#                        {'transcript': 'watch it hurts inside'},
#                        {'transcript': 'what it hurts inside'},
#                        {'transcript': 'watch it has inside'},
#                        {'transcript': 'watch it house inside'}],
#     'final': True}
# audio-chunks/chunk83.wav : What it has inside.
# result2:
# {   'alternative': [   {   'confidence': 0.94562942,
#                            'transcript': 'so it is manually trigger so'},
#                        {'transcript': 'so it is manually trigger solo'},
#                        {'transcript': 'so it is manually trigger sow'},
#                        {'transcript': 'so it is manually trigger sew'},
#                        {'transcript': 'so it is manually trigger Soho'}],
#     'final': True}
# audio-chunks/chunk84.wav : So it is manually trigger so.
# result2:
# {   'alternative': [   {   'confidence': 0.93550271,
#                            'transcript': "there's nothing new to you need to "
#                                          'run it manually'},
#                        {   'transcript': "there's nothing to you need to run "
#                                          'it manually'},
#                        {   'transcript': "there's nothing you need to you need "
#                                          'to run it manually'},
#                        {   'transcript': 'does nothing new to you need to run '
#                                          'it manually'},
#                        {   'transcript': "there's nothing triggering you to "
#                                          'you need to run it manually'}],
#     'final': True}
# audio-chunks/chunk85.wav : There's nothing new to you need to run it manually.
# result2:
# {   'alternative': [   {   'confidence': 0.65959948,
#                            'transcript': 'and warrior Terrace'},
#                        {'transcript': 'and warrior dance'},
#                        {'transcript': 'and very tense'},
#                        {'transcript': 'and warrior tennis'},
#                        {'transcript': 'and what it does'}],
#     'final': True}
# audio-chunks/chunk86.wav : And warrior terrace.
# result2:
# {   'alternative': [   {   'confidence': 0.88554734,
#                            'transcript': 'is talking to'},
#                        {'transcript': 'is to looking to'},
#                        {'transcript': 'is 2 looking to'},
#                        {'transcript': 'is true looking to'},
#                        {'transcript': 'is 2 looking too'}],
#     'final': True}
# audio-chunks/chunk87.wav : Is talking to.
# result2:
# {   'alternative': [   {'confidence': 0.86747622, 'transcript': 'the'},
#                        {'transcript': 'the air'}],
#     'final': True}
# audio-chunks/chunk88.wav : The.
# result2:
# {   'alternative': [   {'confidence': 0.54122031, 'transcript': 'table'},
#                        {'transcript': 'devil'},
#                        {'transcript': 'Dave Hill'},
#                        {'transcript': 'stable'}],
#     'final': True}
# audio-chunks/chunk89.wav : Table.
# result2:
# []
# Error:
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {'confidence': 0.72013903, 'transcript': 'purple one'},
#                        {'transcript': 'table 1'},
#                        {'transcript': 'Google one'},
#                        {'transcript': 'Google 1'},
#                        {'transcript': 'purple 1'}],
#     'final': True}
# audio-chunks/chunk92.wav : Purple one.
# result2:
# {   'alternative': [   {   'confidence': 0.90732086,
#                            'transcript': 'and inside the file'},
#                        {'transcript': 'and inside a file'},
#                        {'transcript': 'and inside to file'},
#                        {'transcript': 'hand inside a file'},
#                        {'transcript': 'hand inside the file'}],
#     'final': True}
# audio-chunks/chunk93.wav : And inside the file.
# result2:
# {   'alternative': [   {   'confidence': 0.93846601,
#                            'transcript': 'and what it will do Easter check'},
#                        {'transcript': "and what it we'll do Easter check"},
#                        {'transcript': 'and what it will do is to check'},
#                        {'transcript': 'and what it will do Easter Czech'},
#                        {'transcript': 'and worry it will do Easter check'}],
#     'final': True}
# audio-chunks/chunk94.wav : And what it will do easter check.
# result2:
# {   'alternative': [   {   'confidence': 0.92825216,
#                            'transcript': 'you for the record is cysts or not '
#                                          "so if it is it's it will"},
#                        {   'transcript': 'you for the record is cysts or not '
#                                          'so if it is if it will'},
#                        {   'transcript': 'you for the record is cysts or not '
#                                          'so if it is is it will'},
#                        {   'transcript': 'for the record is cysts or not so if '
#                                          "it is it's it will"},
#                        {   'transcript': 'for the record is cysts or not so if '
#                                          'it is if it will'}],
#     'final': True}
# audio-chunks/chunk95.wav : You for the record is cysts or not so if it is it's it will.
# result2:
# {   'alternative': [   {   'confidence': 0.87516755,
#                            'transcript': 'update the fields'},
#                        {'transcript': 'update the field'}],
#     'final': True}
# audio-chunks/chunk96.wav : Update the fields.
# result2:
# {   'alternative': [   {   'confidence': 0.94206411,
#                            'transcript': 'and you can see all the fields '
#                                          "you're being updated and only the "
#                                          'ones that can from the repository'},
#                        {   'transcript': 'and you can see all the fields here '
#                                          'being updated and only the ones that '
#                                          'can from the repository'},
#                        {   'transcript': 'and you can see all the fields you '
#                                          'are being updated and only the ones '
#                                          'that can from the repository'},
#                        {   'transcript': 'and you can see all the fields your '
#                                          'being updated and only the ones that '
#                                          'can from the repository'},
#                        {   'transcript': 'and you can see all the fields '
#                                          "you're being updated and only the "
#                                          'one that can from the repository'}],
#     'final': True}
# audio-chunks/chunk97.wav : And you can see all the fields you're being updated and only the ones that can from the repository.
# result2:
# {   'alternative': [   {'confidence': 0.79530716, 'transcript': 'and if the'},
#                        {'transcript': 'and if they'},
#                        {'transcript': "and if they're"},
#                        {'transcript': 'and if they are'},
#                        {'transcript': 'and if they do'}],
#     'final': True}
# audio-chunks/chunk98.wav : And if the.
# result2:
# {   'alternative': [   {   'confidence': 0.92936456,
#                            'transcript': "dirt record doesn't exist that the "
#                                          'result of these compilation here'},
#                        {   'transcript': "the record doesn't exist that the "
#                                          'result of these compilation here'},
#                        {   'transcript': "the Trekker doesn't exist that the "
#                                          'result of these compilation here'},
#                        {   'transcript': "the tracker doesn't exist that the "
#                                          'result of these compilation here'},
#                        {   'transcript': "dirt record doesn't exist at the "
#                                          'result of these compilation here'}],
#     'final': True}
# audio-chunks/chunk99.wav : Dirt record doesn't exist that the result of these compilation here.
# result2:
# {   'alternative': [   {   'confidence': 0.94282657,
#                            'transcript': 'it will create a new record in the'},
#                        {'transcript': 'it will create a new record in the air'},
#                        {'transcript': 'it will create a new record in there'},
#                        {'transcript': 'it will create a new records in the'},
#                        {'transcript': 'it will create a new record in their'}],
#     'final': True}
# audio-chunks/chunk100.wav : It will create a new record in the.
# result2:
# {   'alternative': [   {   'confidence': 0.92561156,
#                            'transcript': 'list of datasets'},
#                        {'transcript': 'list of data sets'}],
#     'final': True}
# audio-chunks/chunk101.wav : List of datasets.
# result2:
# {   'alternative': [   {   'confidence': 0.9283734,
#                            'transcript': 'wait again the fields coming from '
#                                          'there'},
#                        {'transcript': 'wait again the feels coming from there'},
#                        {'transcript': 'wait again the field coming from there'},
#                        {   'transcript': 'wait again the field is coming from '
#                                          'there'},
#                        {   'transcript': 'weight again the fields coming from '
#                                          'there'}],
#     'final': True}
# audio-chunks/chunk102.wav : Wait again the fields coming from there.
# result2:
# {   'alternative': [   {   'confidence': 0.86549151,
#                            'transcript': "and pretty much that's it"},
#                        {'transcript': "and pre-match that's it"},
#                        {'transcript': "I'm pretty much that's it"},
#                        {'transcript': "and pre match that's it"},
#                        {'transcript': 'and pre-match bedsit'}],
#     'final': True}
# audio-chunks/chunk103.wav : And pretty much that's it.
# result2:
# {   'alternative': [   {   'confidence': 0.93422872,
#                            'transcript': 'so once you run this'},
#                        {'transcript': "so one's you run this"},
#                        {'transcript': "so once you're run this"},
#                        {'transcript': "so once you're on this"},
#                        {'transcript': 'so once you run disk'}],
#     'final': True}
# audio-chunks/chunk104.wav : So once you run this.
# result2:
# {   'alternative': [   {   'confidence': 0.91875815,
#                            'transcript': 'the fields that came that come from '
#                                          'that are coming from the repository '
#                                          'will be up to date with the new '
#                                          'data'},
#                        {   'transcript': 'the fields that came that come from '
#                                          'that are coming from the repository '
#                                          'will be updated with the new data'},
#                        {   'transcript': 'the fuels that came that come from '
#                                          'that are coming from the repository '
#                                          'will be up to date with the new '
#                                          'data'},
#                        {   'transcript': 'the fields that came that come from '
#                                          'that are coming from the repository '
#                                          'will be updated with the new data '
#                                          'and'},
#                        {   'transcript': 'the fields that came that come from '
#                                          'that are coming from the repository '
#                                          'will be up-to-date with the new '
#                                          'data'}],
#     'final': True}
# audio-chunks/chunk105.wav : The fields that came that come from that are coming from the repository will be up to date with the new data.
# result2:
# {   'alternative': [   {'confidence': 0.84884185, 'transcript': 'new'},
#                        {'transcript': 'news'},
#                        {'transcript': 'knew'},
#                        {'transcript': 'neu'},
#                        {'transcript': 'Nu'}],
#     'final': True}
# audio-chunks/chunk106.wav : New.
# result2:
# {   'alternative': [   {   'confidence': 0.95096576,
#                            'transcript': 'records will be added in case they '
#                                          "don't exist"},
#                        {   'transcript': 'records will be added in case they '
#                                          "don't assist"},
#                        {   'transcript': 'records will be added in case and '
#                                          "they don't exist"},
#                        {   'transcript': 'record will be added in case they '
#                                          "don't exist"},
#                        {   'transcript': 'records will be added to in case '
#                                          "they don't exist"}],
#     'final': True}
# audio-chunks/chunk107.wav : Records will be added in case they don't exist.
# result2:
# {   'alternative': [   {'confidence': 0.84781259, 'transcript': 'so'},
#                        {'transcript': 'sow'},
#                        {'transcript': 'sew'},
#                        {'transcript': 'solo'},
#                        {'transcript': 'Soho'}],
#     'final': True}
# audio-chunks/chunk108.wav : So.
# result2:
# {   'alternative': [   {   'confidence': 0.939619,
#                            'transcript': 'looking at the microphone now '
#                                          'looking at the camera simply as that '
#                                          'this the other services really need '
#                                          'to have their own'},
#                        {   'transcript': 'looking at the microphone now '
#                                          'looking at the camera simply as that '
#                                          'this the other services will need to '
#                                          'have their own'},
#                        {   'transcript': 'looking at the microphone now '
#                                          'looking at the camera simply as that '
#                                          'this the other sources will need to '
#                                          'have their own'},
#                        {   'transcript': 'looking at the microphone now '
#                                          'looking at the camera simply as that '
#                                          'this the other surfaces really need '
#                                          'to have their own'},
#                        {   'transcript': 'looking at the microphone now '
#                                          'looking at the camera simply as that '
#                                          'this the other services will not '
#                                          'need to have their own'}],
#     'final': True}
# audio-chunks/chunk109.wav : Looking at the microphone now looking at the camera simply as that this the other services really need to have their own.
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {'confidence': 0.7944659, 'transcript': 'arcing'},
#                        {'transcript': 'parsing'},
#                        {'transcript': 'nursing'},
#                        {'transcript': 'passing'},
#                        {'transcript': 'arsing'}],
#     'final': True}
# audio-chunks/chunk111.wav : Arcing.
# result2:
# {   'alternative': [   {   'confidence': 0.94795465,
#                            'transcript': 'notebook this one'},
#                        {'transcript': 'not look this one'},
#                        {'transcript': 'network this one'},
#                        {'transcript': 'not work this one'},
#                        {'transcript': 'note book this one'}],
#     'final': True}
# audio-chunks/chunk112.wav : Notebook this one.
# result2:
# {   'alternative': [   {   'confidence': 0.95193028,
#                            'transcript': 'apart from that procedure after '
#                                          'generating the this file'},
#                        {   'transcript': 'apart from that to procedure after '
#                                          'generating the this file'},
#                        {   'transcript': 'apart from that two procedure after '
#                                          'generating the this file'},
#                        {   'transcript': 'apart from that position after '
#                                          'generating the this file'},
#                        {   'transcript': 'apart from that procedure after '
#                                          'generating the disk file'}],
#     'final': True}
# audio-chunks/chunk113.wav : Apart from that procedure after generating the this file.
# result2:
# {   'alternative': [   {   'confidence': 0.93167228,
#                            'transcript': 'Order Factory resetting to automate '
#                                          'procedures that are the same only '
#                                          'the source will be different'},
#                        {   'transcript': 'Order Factory resetting to automate '
#                                          'procedures that are the same only to '
#                                          'source will be different'},
#                        {   'transcript': 'Order Factory resetting to automate '
#                                          'procedures that are the same only '
#                                          'the sauce will be different'},
#                        {   'transcript': 'Order Factory resetting to automate '
#                                          'procedures that are the same only '
#                                          'the source will be taken'},
#                        {   'transcript': 'Order Factory resetting to automate '
#                                          'procedures that are the same only '
#                                          'two sources will be different'}],
#     'final': True}
# audio-chunks/chunk114.wav : Order factory resetting to automate procedures that are the same only the source will be different.
# result2:
# {   'alternative': [{'confidence': 0.95467669, 'transcript': 'thank you'}],
#     'final': True}
# audio-chunks/chunk115.wav : Thank you.
# result2:
# []
# Error:
#
# Full text: So we at the file share by the. Repository team for instance let's aids day today as today it's not it's one for the best bedford is purpose. Just an example what we need to do first is to upload it. The directory where we handle all the data transformation. And four tet we are going to simply drag and drop from where it is that's it mentioned it's in the downloads folder upload it here. And change the name. What it is expecting that is without the date. We have uploaded. It will ask us to overwrite if you want to overwrite we want to overwrite because it's a new version and now we are ready to run. The. Network that will handle. These transformations so it's this one ira person. And european you can run cell by cell. Or simply. Run all the cells. At 1 so run on. And. Running. Are the films here. Turn my pressure on stick a little bit more time. This one still has 80 records. Ucas produced. Hertford. Generate excel file. That we want. So we have now these excel file. I won't be allowed frazier street what you need to do is create a table on. So for that purpose. Let's download the. File. Sorry. Let's download the file by selecting it. And opening. Cheer. We need to make sure that we select all the fields and all the records. And if you see the instructions here. Select all the fields and all the records. And go. Took the home menu and format as table. So home menu. And then. Format as table. Doesn't matter. David brooks shoes. Any of it. Any. Choose any. Accepted value that's the ones we have selected. It will create the table name. Call. Table 1. Perfect that's what we want. And what part m expecting. As distractions here. So what are you going to do now is to. Applauded. The file. Where it expect to be. Define here so i'm going to replace this. Old one here. Let me close it. Again. Drag and drop so this is the fireworks changed. Drag and drop to replace it. Replace yes replace the the one that it was there. And now we are ready to rent karachi mate i know the address but let me just click here. And you are not seeing me. And we are in power automate. The flow depth we need. Quran. Your track here is update. Rebel datasets. Sew update report datasets. I'm not going to run it now because i don't want to that's not know nothing you want it i'm just going to show you. What it has inside. So it is manually trigger so. There's nothing new to you need to run it manually. And warrior terrace. Is talking to. The. Table. Purple one. And inside the file. And what it will do easter check. You for the record is cysts or not so if it is it's it will. Update the fields. And you can see all the fields you're being updated and only the ones that can from the repository. And if the. Dirt record doesn't exist that the result of these compilation here. It will create a new record in the. List of datasets. Wait again the fields coming from there. And pretty much that's it. So once you run this. The fields that came that come from that are coming from the repository will be up to date with the new data. New. Records will be added in case they don't exist. So. Looking at the microphone now looking at the camera simply as that this the other services really need to have their own. Arcing. Notebook this one. Apart from that procedure after generating the this file. Order factory resetting to automate procedures that are the same only the source will be different. Thank you.
